# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/tutorials/Certification_Trainings/Healthcare/1.3.prepare_CoNLL_from_annotations_for_NER.ipynb)

# %%
import json, os
from google.colab import files

if 'spark_jsl.json' not in os.listdir():
  license_keys = files.upload()
  os.rename(list(license_keys.keys())[0], 'spark_jsl.json')

with open('spark_jsl.json') as f:
    license_keys = json.load(f)

# Defining license key-value pairs as local variables
locals().update(license_keys)
os.environ.update(license_keys)

# %%
# Installing pyspark and spark-nlp
! pip install --upgrade -q pyspark==3.4.1 spark-nlp==$PUBLIC_VERSION

# Installing Spark NLP Healthcare
! pip install --upgrade -q spark-nlp-jsl==$JSL_VERSION  --extra-index-url https://pypi.johnsnowlabs.com/$SECRET

# Installing Spark NLP Display Library for visualization
! pip install -q spark-nlp-display

# %%
import pandas as pd
import numpy as np

import sparknlp
import sparknlp_jsl

from sparknlp.base import *
from sparknlp.annotator import *
from sparknlp_jsl.annotator import *

from pyspark.sql import SparkSession
from pyspark.ml import Pipeline,PipelineModel

params = {"spark.driver.memory":"16G",
          "spark.kryoserializer.buffer.max":"2000M",
          "spark.driver.maxResultSize":"2000M"}

spark = sparknlp_jsl.start(license_keys['SECRET'],params=params)

print ("Spark NLP Version :", sparknlp.version())
print ("Spark NLP_JSL Version :", sparknlp_jsl.version())
# Out:
# Spark NLP Version : 6.1.3
# Spark NLP_JSL Version : 6.1.1

# %% [markdown]
# # 1.3. Prepare CoNLL file from annotations for NER

# %% [markdown]
# ## Healthcare NLP for Data Scientists Course
#
# If you are not familiar with the components in this notebook, you can check [Healthcare NLP for Data Scientists Udemy Course](https://www.udemy.com/course/healthcare-nlp-for-data-scientists/) and the [MOOC Notebooks](https://github.com/JohnSnowLabs/spark-nlp-workshop/tree/master/Spark_NLP_Udemy_MOOC/Healthcare_NLP) for each components.

# %% [markdown]
# ### Entity File
# This dataframe should include at least five  below columns in order:
# *   ['text_id','begin','end','chunk','entity']

# %%
import pandas as pd

# !wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/ChemProt/chemprot_train_entities.csv

train_entities_df = pd.read_csv('chemprot_train_entities.csv')
train_entities_df= train_entities_df[["text_id", "begin", "end", "chunk", "entity"]]
train_entities_df.head()
# Out:
#     text_id  begin   end            chunk    entity
# 0  11319232    242   250        acyl-CoAs  CHEMICAL
# 1  11319232   1193  1200         triacsin  CHEMICAL
# 2  11319232   1441  1447          sucrose  CHEMICAL
# 3  11319232   1637  1651  triacylglycerol  CHEMICAL
# 4  11319232   1702  1710        acyl-CoAs  CHEMICAL

# %% [markdown]
# ### Text File
# This dataframe should include at least two below columns in order:
# *   `['text_id','text']`

# %%
# !wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/tutorials/Certification_Trainings/Healthcare/data/ChemProt/chemprot_train_text.csv
train_text_df = pd.read_csv('chemprot_train_text.csv')
train_text_df.head()
# Out:
#     text_id                                               text
# 0  16357751  Selective costimulation modulators: a novel ap...
# 1  14967461  Emerging role of epidermal growth factor recep...
# 2  23468099  Effects of chronic social defeat stress on beh...
# 3  23293962  Hepatocyte growth factor activator inhibitor t...
# 4   7678677  Alprenolol and bromoacetylalprenololmenthane a...

# %%
def make_conll(text:pd.DataFrame, entity:pd.DataFrame,
               save_tag:bool=True,
               save_conll:bool=True,
               verbose:bool=None,
               begin_deviation:int=0,
               end_deviation:int=0 )->str:

    df_text = text.iloc[:,[0,1]]
    df_entity = entity.iloc[:,[0,1,2,3,4]]
    df_text.columns = ['text_id','text']
    df_entity.columns = ['text_id','begin','end','chunk','entity']
    entity_list = list(df_entity.entity.unique())


    ########--------------1.tag transformation function------------########

    def transform_text(text, entities, verbose=None):

        tag_list=[]
        for entity in entities.iterrows():

            begin = entity[1][1] + begin_deviation
            end = entity[1][2] + end_deviation
            chunk = entity[1][3]
            tag = entity[1][4]
            text = text[:end] + f' </END_NER:{tag}> ' + text[end:]
            text = text[:begin] + f' <START_NER:{tag}> ' + text[begin:]
            tag_list.append(tag)

        sum_of_added_entity = Counter(tag_list)
        sum_of_entity = Counter(entities['entity'].values)

        if verbose:
            print(f'Processed text id   : {entities.text_id.values[:1]}')
            print(f'Original Entities   : {sum_of_entity}\nAdded Entities      : {sum_of_added_entity}')
            print(f'Number Equality     : {sum_of_added_entity == sum_of_entity}')
            print("=="*40)

        if not sum_of_entity == sum_of_added_entity:
            print("There is a problem in text id:")
            print(entities.text_id.values[0])
            raise Exception("Check this text!")

        return text


    ######---------------2.apply_transform_text function ----------------#######

    def apply_tag_ner(df_text, df_entity, save=None, verbose=None):

        for text_id in tqdm(df_text.text_id):
            text  = df_text.loc[df_text['text_id']==text_id]['text'].values[0]
            entities  = df_entity.loc[(df_entity['text_id']==text_id)].sort_values(by='begin',ascending=False)

            df_text.loc[df_text['text_id']==text_id, 'text'] = transform_text(text, entities, verbose=verbose)

        if save:
            df_text.to_csv("text_with_ner_tag.csv", index=False, encoding='utf8')

        return df_text


    ##########----------------3.RUNNING TAG FUNCTION---------------#############

    print("Text tagging starting. Applying entities to whole text...\n")
    df = apply_tag_ner(df_text, df_entity, save=save_tag, verbose=verbose)


    ###########---------------4.Spark Pipeline-----------------------###########

    def spark_pipeline(df):
        spark_df = spark.createDataFrame(df)

        documentAssembler = DocumentAssembler()\
            .setInputCol("text")\
            .setOutputCol("document")\
            .setCleanupMode("shrink")

        sentenceDetector = SentenceDetector()\
            .setInputCols(['document'])\
            .setOutputCol('sentences')\
            .setExplodeSentences(True)

        tokenizer = Tokenizer() \
            .setInputCols(["sentences"]) \
            .setOutputCol("token")

        nlpPipeline = Pipeline(stages=[documentAssembler, sentenceDetector, tokenizer ])

        empty_df = spark.createDataFrame([['']]).toDF("text")
        pipelineModel = nlpPipeline.fit(empty_df)

        result = pipelineModel.transform(spark_df.select(['text']))


        return result.select('token.result').toPandas()
    print("\n\nSpark pipeline is running...")
    df_final = spark_pipeline(df)


    #########--------------5.CoNLL Function--------------------#############

    def build_conll(df_final, tag_list, save=None):

        header = "-DOCSTART- -X- -X- O\n\n"
        conll_text = ""
        chunks = []
        tag_list = tag_list
        tag = 'O'      # token tag
        ct = 'B'       # chunk tag part B or I

        for sentence_tokens in tqdm(df_final.result[:]):
            for token in sentence_tokens:
                if token.startswith("<START_NER:"):
                    tag = token.split(':')[1][:-1]
                    if tag not in tag_list:
                        tag = 'O'
                        conll_text += f'{token} NN NN {tag}\n'

                    continue

                if token.startswith("</END_NER:") and tag != 'O':
                    for i, chunk in enumerate(chunks):
                        ct = 'B' if i == 0 else 'I'
                        conll_text += f'{chunk} NNP NNP {ct}-{tag}\n'

                    chunks=[]
                    tag='O'
                    continue

                if tag != 'O':
                    chunks.append(token)
                    continue

                if tag == 'O':
                    conll_text += f'{token} NN NN {tag}\n'
                    continue

            conll_text += '\n'

        if save:
            with open("conll2003_text_file.conll", "w+", encoding='utf8') as f:
                f.write(header)
                f.write(conll_text)

        print("\nDONE!")
        return conll_text


    ########----------------6.RUNNING CONLL FUNCTION--------------------########

    print("Conll file is being created...\n")
    return build_conll(df_final, tag_list=entity_list, save=save_conll)

# %% [markdown]
# ## Running the Create CoNLL Function

# %%
import sys, pkgutil, subprocess
if pkgutil.find_loader("tqdm") is None:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "tqdm"])

from tqdm.auto import tqdm
from collections import Counter
# Out:
# /tmp/ipython-input-3119906318.py:2: DeprecationWarning: 'pkgutil.find_loader' is deprecated and slated for removal in Python 3.14; use importlib.util.find_spec() instead
#   if pkgutil.find_loader("tqdm") is None:

# %%
# if you want tagged text or conll file saved in the current directory: just make default 'save_tag' or 'save_conll' parameters True.
conll_text = make_conll(train_text_df, train_entities_df, save_conll=True)
# Out:
# Text tagging starting. Applying entities to whole text...
#   0%|          | 0/1020 [00:00<?, ?it/s]
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# ...
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# /tmp/ipython-input-1526102849.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   begin = entity[1][1] + begin_deviation
# /tmp/ipython-input-1526102849.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = entity[1][2] + end_deviation
# /tmp/ipython-input-1526102849.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chunk = entity[1][3]
# /tmp/ipython-input-1526102849.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tag = entity[1][4]
# Spark pipeline is running...
# Conll file is being created...
#   0%|          | 0/10835 [00:00<?, ?it/s]
# DONE!

# %%
# Checking conll string
print(conll_text[:532])
# Out:
# Selective NN NN O
# costimulation NN NN O
# modulators NN NN O
# : NN NN O
# a NN NN O
# novel NN NN O
# approach NN NN O
# for NN NN O
# the NN NN O
# treatment NN NN O
# of NN NN O
# rheumatoid NN NN O
# arthritis NN NN O
# . NN NN O
#
# T NN NN O
# cells NN NN O
# have NN NN O
# a NN NN O
# central NN NN O
# role NN NN O
# in NN NN O
# the NN NN O
# orchestration NN NN O
# of NN NN O
# the NN NN O
# immune NN NN O
# pathways NN NN O
# that NN NN O
# contribute NN NN O
# to NN NN O
# the NN NN O
# inflammation NN NN O
# and NN NN O
# joint NN NN O
# destruction NN NN O
# characteristic NN NN O

# %% [markdown]
# ### Saving CoNLL File

# %%
with open("conll2003_text_file.conll", "w+", encoding='utf8') as f:
    f.write("-DOCSTART- -X- -X- O\n\n")
    f.write(conll_text)

# %% [markdown]
# # Reading CoNLL File by Using CoNLL Reader

# %%
from sparknlp.training import CoNLL

# %%
data = CoNLL().readDataset(spark, "/content/conll2003_text_file.conll")
data.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |                text|            document|            sentence|               token|                 pos|               label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |Selective costimu...|[{document, 0, 96...|[{document, 0, 96...|[{token, 0, 8, Se...|[{pos, 0, 8, NN, ...|[{named_entity, 0...|
# |T cells have a ce...|[{document, 0, 17...|[{document, 0, 17...|[{token, 0, 0, T,...|[{pos, 0, 0, NN, ...|[{named_entity, 0...|
# |The requirement f...|[{document, 0, 22...|[{document, 0, 22...|[{token, 0, 2, Th...|[{pos, 0, 2, NN, ...|[{named_entity, 0...|
# |This approach is ...|[{document, 0, 78...|[{document, 0, 78...|[{token, 0, 3, Th...|[{pos, 0, 3, NN, ...|[{named_entity, 0...|
# |it targets events...|[{document, 0, 13...|[{document, 0, 13...|[{token, 0, 1, it...|[{pos, 0, 1, NN, ...|[{named_entity, 0...|
# |The fusion protei...|[{document, 0, 23...|[{document, 0, 23...|[{token, 0, 2, Th...|[{pos, 0, 2, NN, ...|[{named_entity, 0...|
# |Abatacept dose-de...|[{document, 0, 19...|[{document, 0, 19...|[{token, 0, 8, Ab...|[{pos, 0, 8, NN, ...|[{named_entity, 0...|
# |Recent studies ha...|[{document, 0, 26...|[{document, 0, 26...|[{token, 0, 5, Re...|[{pos, 0, 5, NN, ...|[{named_entity, 0...|
# |This efficacy inc...|[{document, 0, 10...|[{document, 0, 10...|[{token, 0, 3, Th...|[{pos, 0, 3, NN, ...|[{named_entity, 0...|
# |Abatacept has als...|[{document, 0, 72...|[{document, 0, 72...|[{token, 0, 8, Ab...|[{pos, 0, 8, NN, ...|[{named_entity, 0...|
# |This article revi...|[{document, 0, 16...|[{document, 0, 16...|[{token, 0, 3, Th...|[{pos, 0, 3, NN, ...|[{named_entity, 0...|
# |This clinical exp...|[{document, 0, 14...|[{document, 0, 14...|[{token, 0, 3, Th...|[{pos, 0, 3, NN, ...|[{named_entity, 0...|
# |Emerging role of ...|[{document, 0, 11...|[{document, 0, 11...|[{token, 0, 7, Em...|[{pos, 0, 7, NN, ...|[{named_entity, 0...|
# |Combination chemo...|[{document, 0, 11...|[{document, 0, 11...|[{token, 0, 10, C...|[{pos, 0, 10, NN,...|[{named_entity, 0...|
# |Meta-analyses hav...|[{document, 0, 18...|[{document, 0, 18...|[{token, 0, 12, M...|[{pos, 0, 12, NN,...|[{named_entity, 0...|
# |Just as important...|[{document, 0, 10...|[{document, 0, 10...|[{token, 0, 3, Ju...|[{pos, 0, 3, NN, ...|[{named_entity, 0...|
# |Newer agents , in...|[{document, 0, 18...|[{document, 0, 18...|[{token, 0, 4, Ne...|[{pos, 0, 4, NN, ...|[{named_entity, 0...|
# |Despite their con...|[{document, 0, 19...|[{document, 0, 19...|[{token, 0, 6, De...|[{pos, 0, 6, NN, ...|[{named_entity, 0...|
# |It is doubtful th...|[{document, 0, 13...|[{document, 0, 13...|[{token, 0, 1, It...|[{pos, 0, 1, NN, ...|[{named_entity, 0...|
# |The thrust of cur...|[{document, 0, 16...|[{document, 0, 16...|[{token, 0, 2, Th...|[{pos, 0, 2, NN, ...|[{named_entity, 0...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Alternative Method
#
# This method may take some time depending on the size of your data.

# %%
train_entities_df.head()
# Out:
#     text_id  begin   end            chunk    entity
# 0  11319232    242   250        acyl-CoAs  CHEMICAL
# 1  11319232   1193  1200         triacsin  CHEMICAL
# 2  11319232   1441  1447          sucrose  CHEMICAL
# 3  11319232   1637  1651  triacylglycerol  CHEMICAL
# 4  11319232   1702  1710        acyl-CoAs  CHEMICAL

# %%
train_text_df.head()
# Out:
#     text_id                                               text
# 0  16357751  Selective costimulation modulators: a novel ap...
# 1  14967461  Emerging role of epidermal growth factor recep...
# 2  23468099  Effects of chronic social defeat stress on beh...
# 3  23293962  Hepatocyte growth factor activator inhibitor t...
# 4   7678677  Alprenolol and bromoacetylalprenololmenthane a...

# %%
spark_df = spark.createDataFrame(train_text_df)
spark_df.show()
# Out:
# +--------+--------------------+
# | text_id|                text|
# +--------+--------------------+
# |16357751|Selective costimu...|
# |14967461|Emerging role of ...|
# |23468099|Effects of chroni...|
# |23293962|Hepatocyte growth...|
# | 7678677|Alprenolol and br...|
# |16554356|Covalent linkage ...|
# |16789740|Discovery and opt...|
# | 7526860|Keratinocyte grow...|
# |17199504|Configuration of ...|
# |16437532|Cholinesterase in...|
# |11716850|The effects of mi...|
# |23487168|A systematic comp...|
# |23019138|Diuretic effects ...|
# |12065695|Nonsteroidal anti...|
# |23214423|Anisotropy of che...|
# |16840830|Two novel mutatio...|
# |15736931|Mutation of argin...|
# |23414802|Discovery of nove...|
# |23578689|Conformationally ...|
# |15908512|Beta1 adrenergic ...|
# +--------+--------------------+
# only showing top 20 rows

# %%
documentAssembler = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

sentenceDetector = SentenceDetector()\
    .setInputCols(['document'])\
    .setOutputCol('sentence')

tokenizer = Tokenizer()\
    .setInputCols(["sentence"])\
    .setOutputCol("token")

nlpPipeline = Pipeline(
    stages=[
        documentAssembler,
        sentenceDetector,
        tokenizer])

result = nlpPipeline.fit(spark_df).transform(spark_df)

# %%
result.select("text_id",F.explode(F.arrays_zip(result.token.result,
                                            result.token.begin,
                                            result.token.end,
                                            result.token.metadata)).alias("cols"))\
                  .select("text_id",F.expr("cols['0']").alias("token"),
                          F.expr("cols['3']['sentence']").alias("sentence_id"),
                          F.expr("cols['1']").alias("token_begin"),
                          F.expr("cols['2']").alias("token_end")).show(50, truncate=100)
# Out:
# +--------+--------------+-----------+-----------+---------+
# | text_id|         token|sentence_id|token_begin|token_end|
# +--------+--------------+-----------+-----------+---------+
# |16357751|     Selective|          0|          0|        8|
# |16357751| costimulation|          0|         10|       22|
# |16357751|    modulators|          0|         24|       33|
# |16357751|             :|          0|         34|       34|
# |16357751|             a|          0|         36|       36|
# |16357751|         novel|          0|         38|       42|
# |16357751|      approach|          0|         44|       51|
# |16357751|           for|          0|         53|       55|
# |16357751|           the|          0|         57|       59|
# |16357751|     treatment|          0|         61|       69|
# |16357751|            of|          0|         71|       72|
# |16357751|    rheumatoid|          0|         74|       83|
# |16357751|     arthritis|          0|         85|       93|
# |16357751|             .|          0|         94|       94|
# |16357751|             T|          1|         96|       96|
# |16357751|         cells|          1|         98|      102|
# |16357751|          have|          1|        104|      107|
# |16357751|             a|          1|        109|      109|
# |16357751|       central|          1|        111|      117|
# |16357751|          role|          1|        119|      122|
# |16357751|            in|          1|        124|      125|
# |16357751|           the|          1|        127|      129|
# |16357751| orchestration|          1|        131|      143|
# |16357751|            of|          1|        145|      146|
# |16357751|           the|          1|        148|      150|
# |16357751|        immune|          1|        152|      157|
# |16357751|      pathways|          1|        159|      166|
# |16357751|          that|          1|        168|      171|
# |16357751|    contribute|          1|        173|      182|
# |16357751|            to|          1|        184|      185|
# |16357751|           the|          1|        187|      189|
# |16357751|  inflammation|          1|        191|      202|
# |16357751|           and|          1|        204|      206|
# |16357751|         joint|          1|        208|      212|
# |16357751|   destruction|          1|        214|      224|
# |16357751|characteristic|          1|        226|      239|
# |16357751|            of|          1|        241|      242|
# |16357751|    rheumatoid|          1|        244|      253|
# |16357751|     arthritis|          1|        255|      263|
# |16357751|             (|          1|        265|      265|
# |16357751|            RA|          1|        266|      267|
# |16357751|            ).|          1|        268|      269|
# |16357751|           The|          2|        271|      273|
# |16357751|   requirement|          2|        275|      285|
# |16357751|           for|          2|        287|      289|
# |16357751|             a|          2|        291|      291|
# |16357751|          dual|          2|        293|      296|
# |16357751|        signal|          2|        298|      303|
# |16357751|           for|          2|        305|      307|
# |16357751|        T-cell|          2|        309|      314|
# +--------+--------------+-----------+-----------+---------+
# only showing top 50 rows

# %%
test_token_df=result.select("text_id",F.explode(F.arrays_zip(result.token.result,
                                            result.token.begin,
                                            result.token.end,
                                            result.token.metadata)).alias("cols"))\
                  .select("text_id",F.expr("cols['0']").alias("token"),
                          F.expr("cols['3']['sentence']").alias("sentence_id"),
                          F.expr("cols['1']").alias("begin"),
                          F.expr("cols['2']").alias("end")).toPandas()

# %%
new_token_df = test_token_df.copy()
new_token_df["entity"] = "O"

inner_label=False
for i, token_row in test_token_df.iterrows():
    text_id = token_row.text_id
    token_begin = token_row.begin
    token_end = token_row.end


    for j, entity_row in train_entities_df[train_entities_df.text_id == text_id].iterrows():
        entity_begin = entity_row.begin
        entity_end = entity_row.end


        if (entity_begin<= token_begin) and (token_end<= entity_end):
            if new_token_df.loc[i-1,"entity"] == new_token_df.loc[i,"entity"] :
                new_token_df.loc[i,"entity"] = "B-"+(entity_row.entity)
            else:
                new_token_df.loc[i,"entity"] = "I-"+(entity_row.entity)

# %%
new_token_df.to_csv("train_new_token_df.csv",index=False)

# %%
conll_text = "-DOCSTART- -X- -0- O\n\n"
sentence_index = 0
document_index = 0


for i, row in new_token_df.iterrows():
    if document_index == row.text_id:

        if sentence_index == row.sentence_id:
            conll_text += f"{row.token} NN NN {row.entity}\n"

        else:
            conll_text += "\n"
            sentence_index = row.sentence_id
            conll_text += f"{row.token} NN NN {row.entity}\n"

    else:
        document_index = row.text_id
        conll_text += f"\n-DOCSTART- -X- -{row.text_id}- O\n"
        conll_text += "\n"
        conll_text += f"{row.token} NN NN {row.entity}\n"
        sentence_index = row.sentence_id
# print(conll_text)

# %%
print(conll_text[1000:])
# Out:
# O
# required NN NN O
# for NN NN O
# this NN NN O
# activation NN NN O
# has NN NN O
# led NN NN O
# to NN NN O
# a NN NN O
# new NN NN O
# approach NN NN O
# to NN NN O
# RA NN NN O
# therapy NN NN O
# . NN NN O
#
# This NN NN O
# approach NN NN O
# is NN NN O
# mechanistically NN NN O
# distinct NN NN O
# from NN NN O
# other NN NN O
# currently NN NN O
# used NN NN O
# therapies NN NN O
# ; NN NN O
#
# it NN NN O
# targets NN NN O
# events NN NN O
# early NN NN O
# rather NN NN O
# than NN NN O
# late NN NN O
# in NN NN O
# the NN NN O
# immune NN NN O
# cascade NN NN O
# , NN NN O
# and NN NN O
# it NN NN O
# results NN NN O
# in NN NN O
# immunomodulation NN NN O
# rather NN NN O
# than NN NN O
# complete NN NN O
# immunosuppression NN NN O
# . NN NN O
#
# The NN NN O
# fusion NN NN O
# protein NN NN O
# abatacept NN NN O
# is NN NN O
# a NN NN O
# selective NN NN O
# costimulation NN NN O
# modulator NN NN O
# that NN NN O
# avidly NN NN O
# binds NN NN O
# to NN NN O
# the NN NN O
# CD80/CD86 NN NN O
# ligands NN NN O
# on NN NN O
# an NN NN O
# antigen-presenting NN NN O
# cell NN NN O
# , NN NN O
# resulting NN NN O
# in NN NN O
# the NN NN O
# inability NN NN O
# of NN NN O
# these NN NN O
# ligands NN NN O
# to NN NN O
# engage NN NN O
# the NN NN O
# CD28 NN NN B-GENE-N
# receptor NN NN I-GENE-N
# on NN NN O
# the NN NN O
# T NN NN O
# cell NN NN O
# . NN NN O
#
# Abatacept NN NN O
# dose-dependently NN NN O
# reduces NN NN O
# T-cell NN NN O
# proliferation NN NN O
# , NN NN O
# serum NN NN O
# concentrations NN NN O
# of NN NN O
# acute-phase NN NN O
# reactants NN NN O
# , NN NN O
# and NN NN O
# other NN NN O
# markers NN NN O
# of NN NN O
# inflammation NN NN O
# , NN NN O
# including NN NN O
# the NN NN O
# production NN NN O
# of NN NN O
# rheumatoid NN NN O
# factor NN NN O
# by NN NN O
# B NN NN O
# cells NN NN O
# . NN NN O
#
# Recent NN NN O
# studies NN NN O
# have NN NN O
# provided NN NN O
# consistent NN NN O
# evidence NN NN O
# that NN NN O
# treatment NN NN O
# with NN NN O
# abatacept NN NN O
# results NN NN O
# in NN NN O
# a NN NN O
# rapid NN NN O
# onset NN NN O
# of NN NN O
# efficacy NN NN O
# that NN NN O
# is NN NN O
# maintained NN NN O
# over NN NN O
# the NN NN O
# course NN NN O
# of NN NN O
# treatment NN NN O
# in NN NN O
# patients NN NN O
# with NN NN O
# inadequate NN NN O
# response NN NN O
# to NN NN O
# methotrexate NN NN B-CHEMICAL
# and NN NN O
# anti-tumor NN NN O
# necrosis NN NN B-GENE-N
# factor NN NN I-GENE-N
# therapies NN NN O
# . NN NN O
#
# This NN NN O
# efficacy NN NN O
# includes NN NN O
# patient-centered NN NN O
# outcomes NN NN O
# and NN NN O
# radiographic NN NN O
# measurement NN NN O
# of NN NN O
# disease NN NN O
# progression NN NN O
# . NN NN O
#
# Abatacept NN NN O
# has NN NN O
# also NN NN O
# demonstrated NN NN O
# a NN NN O
# very NN NN O
# favorable NN NN O
# safety NN NN O
# profile NN NN O
# to NN NN O
# date NN NN O
# . NN NN O
#
# This NN NN O
# article NN NN O
# reviews NN NN O
# the NN NN O
# rationale NN NN O
# for NN NN O
# this NN NN O
# therapeutic NN NN O
# approach NN NN O
# and NN NN O
# highlights NN NN O
# some NN NN O
# of NN NN O
# the NN NN O
# recent NN NN O
# studies NN NN O
# that NN NN O
# demonstrate NN NN O
# the NN NN O
# benefits NN NN O
# obtained NN NN O
# by NN NN O
# using NN NN O
# abatacept NN NN O
# . NN NN O
#
# This NN NN O
# clinical NN NN O
# experience NN NN O
# indicates NN NN O
# that NN NN O
# abatacept NN NN O
# is NN NN O
# a NN NN O
# significant NN NN O
# addition NN NN O
# to NN NN O
# the NN NN O
# therapeutic NN NN O
# armamentarium NN NN O
# for NN NN O
# the NN NN O
# management NN NN O
# of NN NN O
# patients NN NN O
# with NN NN O
# RA NN NN O
# . NN NN O
#
# -DOCSTART- -X- -14967461- O
#
# Emerging NN NN O
# role NN NN O
# of NN NN O
# epidermal NN NN B-GENE-Y
# growth NN NN I-GENE-Y
# factor NN NN I-GENE-Y
# receptor NN NN I-GENE-Y
# inhibition NN NN O
# in NN NN O
# therapy NN NN O
# for NN NN O
# advanced NN NN O
# malignancy NN NN O
# : NN NN O
# focus NN NN O
# on NN NN O
# NSCLC NN NN O
# . NN NN O
#
# Combination NN NN O
# chemotherapy NN NN O
# regimens NN NN O
# have NN NN O
# emerged NN NN O
# as NN NN O
# the NN NN O
# standard NN NN O
# approach NN NN O
# in NN NN O
# advanced NN NN O
# non-small-cell NN NN O
# lung NN NN O
# cancer NN NN O
# . NN NN O
#
# Meta-analyses NN NN O
# have NN NN O
# demonstrated NN NN O
# a NN NN O
# 2-month NN NN O
# increase NN NN O
# in NN NN O
# median NN NN O
# survival NN NN O
# after NN NN O
# platinum-based NN NN O
# therapy NN NN O
# vs NN NN O
# . NN NN O
# best NN NN O
# supportive NN NN O
# care NN NN O
# , NN NN O
# and NN NN O
# an NN NN O
# absolute NN NN O
# 10% NN NN O
# improvement NN NN O
# in NN NN O
# the NN NN O
# 1-year NN NN O
# survival NN NN O
# rate NN NN O
# . NN NN O
#
# Just NN NN O
# as NN NN O
# importantly NN NN O
# , NN NN O
# cytotoxic NN NN O
# therapy NN NN O
# has NN NN O
# produced NN NN O
# benefits NN NN O
# in NN NN O
# symptom NN NN O
# control NN NN O
# and NN NN O
# quality NN NN O
# of NN NN O
# life NN NN O
# . NN NN O
#
# Newer NN NN O
# agents NN NN O
# , NN NN O
# including NN NN O
# the NN NN O
# taxanes NN NN B-CHEMICAL
# , NN NN O
# vinorelbine NN NN B-CHEMICAL
# , NN NN O
# gemcitabine NN NN B-CHEMICAL
# , NN NN O
# and NN NN O
# irinotecan NN NN B-CHEMICAL
# , NN NN O
# have NN NN O
# expanded NN NN O
# our NN NN O
# therapeutic NN NN O
# options NN NN O
# in NN NN O
# the NN NN O
# treatment NN NN O
# of NN NN O
# advanced NN NN O
# non-small-cell NN NN O
# lung NN NN O
# cancer NN NN O
# . NN NN O
#
# Despite NN NN O
# their NN NN O
# contributions NN NN O
# , NN NN O
# we NN NN O
# have NN NN O
# reached NN NN O
# a NN NN O
# therapeutic NN NN O
# plateau NN NN O
# , NN NN O
# with NN NN O
# response NN NN O
# rates NN NN O
# seldom NN NN O
# exceeding NN NN O
# 30-40% NN NN O
# in NN NN O
# cooperative NN NN O
# group NN NN O
# studies NN NN O
# and NN NN O
# 1-year NN NN O
# survival NN NN O
# rates NN NN O
# stable NN NN O
# between NN NN O
# 30% NN NN O
# and NN NN O
# 40% NN NN O
# . NN NN O
#
# It NN NN O
# is NN NN O
# doubtful NN NN O
# that NN NN O
# substituting NN NN O
# one NN NN O
# agent NN NN O
# for NN NN O
# another NN NN O
# in NN NN O
# various NN NN O
# combinations NN NN O
# will NN NN O
# lead NN NN O
# to NN NN O
# any NN NN O
# further NN NN O
# improvement NN NN O
# in NN NN O
# these NN NN O
# rates NN NN O
# . NN NN O
#
# The NN NN O
# thrust NN NN O
# of NN NN O
# current NN NN O
# research NN NN O
# has NN NN O
# focused NN NN O
# on NN NN O
# targeted NN NN O
# therapy NN NN O
# , NN NN O
# and NN NN O
# epidermal NN NN B-GENE-Y
# growth NN NN I-GENE-Y
# factor NN NN I-GENE-Y
# receptor NN NN I-GENE-Y
# inhibition NN NN O
# is NN NN O
# one NN NN O
# of NN NN O
# the NN NN O
# most NN NN O
# promising NN NN O
# clinical NN NN O
# strategies NN NN O
# . NN NN O
#
# Epidermal NN NN B-GENE-Y
# growth NN NN I-GENE-Y
# factor NN NN I-GENE-Y
# receptor NN NN I-GENE-Y
# inhibitors NN NN O
# currently NN NN O
# under NN NN O
# investigation NN NN O
# include NN NN O
# the NN NN O
# small NN NN O
# molecules NN NN O
# gefitinib NN NN B-CHEMICAL
# ( NN NN O
# Iressa NN NN B-CHEMICAL
# , NN NN O
# ZD1839 NN NN B-CHEMICAL
# ) NN NN O
# and NN NN O
# erlotinib NN NN B-CHEMICAL
# ( NN NN O
# Tarceva NN NN B-CHEMICAL
# , NN NN O
# OSI-774 NN NN B-CHEMICAL
# ), NN NN O
# as NN NN O
# well NN NN O
# as NN NN O
# monoclonal NN NN O
# antibodies NN NN O
# such NN NN O
# as NN NN O
# cetuximab NN NN B-CHEMICAL
# ( NN NN O
# IMC-225 NN NN B-CHEMICAL
# , NN NN O
# Erbitux NN NN B-CHEMICAL
# ). NN NN O
#
# Agents NN NN O
# that NN NN O
# have NN NN O
# only NN NN O
# begun NN NN O
# to NN NN O
# undergo NN NN O
# clinical NN NN O
# evaluation NN NN O
# include NN NN O
# CI-1033 NN NN B-CHEMICAL
# , NN NN O
# an NN NN O
# irreversible NN NN O
# pan-erbB NN NN O
# tyrosine NN NN I-GENE-N
# kinase NN NN I-GENE-N
# inhibitor NN NN O
# , NN NN O
# and NN NN O
# PKI166 NN NN B-CHEMICAL
# and NN NN O
# GW572016 NN NN B-CHEMICAL
# , NN NN O
# both NN NN O
# examples NN NN O
# of NN NN O
# dual NN NN O
# kinase NN NN B-GENE-N
# inhibitors NN NN O
# ( NN NN O
# inhibiting NN NN O
# epidermal NN NN B-GENE-Y
# growth NN NN I-GENE-Y
# factor NN NN I-GENE-Y
# receptor NN NN I-GENE-Y
# and NN NN O
# Her2 NN NN B-GENE-Y
# ). NN NN O
#
# Preclinical NN NN O
# models NN NN O
# have NN NN O
# demonstrated NN NN O
# synergy NN NN O
# for NN NN O
# all NN NN O
# these NN NN O
# agents NN NN O
# in NN NN O
# combination NN NN O
# with NN NN O
# either NN NN O
# chemotherapy NN NN O
# or NN NN O
# radiotherapy NN NN O
# , NN NN O
# leading NN NN O
# to NN NN O
# great NN NN O
# enthusiasm NN NN O
# regarding NN NN O
# their NN NN O
# ultimate NN NN O
# contribution NN NN O
# to NN NN O
# lung NN NN O
# cancer NN NN O
# therapy NN NN O
# . NN NN O
#
# However NN NN O
# , NN NN O
# serious NN NN O
# clinical NN NN O
# challenges NN NN O
# persist NN NN O
# . NN NN O
#
# These NN NN O
# include NN NN O
# the NN NN O
# identification NN NN O
# of NN NN O
# the NN NN O
# optimal NN NN O
# dose NN NN O
#
# ( NN NN O
# s NN NN O
# ); NN NN O
#
# the NN NN O
# proper NN NN O
# integration NN NN O
# of NN NN O
# these NN NN O
# agents NN NN O
# into NN NN O
# popular NN NN O
# , NN NN O
# established NN NN O
# cytotoxic NN NN O
# regimens NN NN O
# ; NN NN O
#
# and NN NN O
# the NN NN O
# selection NN NN O
# of NN NN O
# the NN NN O
# optimal NN NN O
# setting NN NN O
#
# ( NN NN O
# s NN NN O
# ) NN NN O
# in NN NN O
# which NN NN O
# to NN NN O
# test NN NN O
# these NN NN O
# compounds NN NN O
# . NN NN O
#
# Both NN NN O
# gefitinib NN NN B-CHEMICAL
# and NN NN O
# erlotinib NN NN B-CHEMICAL
# have NN NN O
# shown NN NN O
# clinical NN NN O
# activity NN NN O
# in NN NN O
# pretreated NN NN O
# , NN NN O
# advanced NN NN O
# non-small-cell NN NN O
# lung NN NN O
# cancer NN NN O
# , NN NN O
# but NN NN O
# placebo-controlled NN NN O
# randomized NN NN O
# Phase NN NN O
# III NN NN O
# studies NN NN O
# evaluating NN NN O
# gefitinib NN NN B-CHEMICAL
# in NN NN O
# combination NN NN O
# with NN NN O
# standard NN NN O
# cytotoxic NN NN O
# therapy NN NN O
# , NN NN O
# to NN NN O
# our NN NN O
# chagrin NN NN O
# , NN NN O
# have NN NN O
# failed NN NN O
# to NN NN O
# demonstrate NN NN O
# a NN NN O
# survival NN NN O
# advantage NN NN O
# compared NN NN O
# with NN NN O
# chemotherapy NN NN O
# alone NN NN O
# . NN NN O
#
# -DOCSTART- -X- -23468099- O
#
# Effects NN NN O
# of NN NN O
# chronic NN NN O
# social NN NN O
# defeat NN NN O
# stress NN NN O
# on NN NN O
# behavior NN NN O
# and NN NN O
# choline NN NN I-GENE-Y
# acetyltransferase NN NN I-GENE-Y
# , NN NN O
# 78-kDa NN NN B-GENE-Y
# glucose-regulated NN NN I-GENE-Y
# protein NN NN I-GENE-Y
# , NN NN O
# and NN NN O
# CCAAT/enhancer-binding NN NN B-GENE-Y
# protein NN NN I-GENE-Y
# ( NN NN I-GENE-Y
# C/EBP NN NN I-GENE-Y
# ) NN NN I-GENE-Y
# homologous NN NN I-GENE-Y
# protein NN NN I-GENE-Y
# in NN NN O
# adult NN NN O
# mice NN NN O
# . NN NN O
#
# RATIONALE NN NN O
# : NN NN O
# Social NN NN O
# defeat NN NN O
# stress NN NN O
# induces NN NN O
# physiological NN NN O
# and NN NN O
# behavioral NN NN O
# symptoms NN NN O
# , NN NN O
# including NN NN O
# anxiety NN NN O
# , NN NN O
# anhedonia NN NN O
# , NN NN O
# immune NN NN O
# deficits NN NN O
# , NN NN O
# and NN NN O
# altered NN NN O
# expression NN NN O
# of NN NN O
# key NN NN O
# brain NN NN O
# genes NN NN O
# . NN NN O
#
# OBJECTIVES NN NN O
# : NN NN O
# The NN NN O
# present NN NN O
# study NN NN O
# investigated NN NN O
# the NN NN O
# effects NN NN O
# of NN NN O
# social NN NN O
# defeat NN NN O
# stress NN NN O
# on NN NN O
# the NN NN O
# behaviors NN NN O
# and NN NN O
# expressions NN NN O
# of NN NN O
# Chat NN NN B-GENE-Y
# , NN NN O
# Grp78 NN NN B-GENE-Y
# , NN NN O
# and NN NN O
# chop NN NN B-GENE-Y
# in NN NN O
# the NN NN O
# brains NN NN O
# of NN NN O
# adult NN NN O
# mice NN NN O
# . NN NN O
#
# METHODS NN NN O
# : NN NN O
# Adult NN NN O
# mice NN NN O
# were NN NN O
# divided NN NN O
# into NN NN O
# susceptible NN NN O
# and NN NN O
# unsusceptible NN NN O
# groups NN NN O
# after NN NN O
# 10 days NN NN O
# of NN NN O
# social NN NN O
# defeat NN NN O
# stress NN NN O
# . NN NN O
#
# In NN NN O
# experiment NN NN O
# 1 NN NN O
# , NN NN O
# behavioral NN NN O
# tests NN NN O
# were NN NN O
# conducted NN NN O
# , NN NN O
# and NN NN O
# brains NN NN O
# were NN NN O
# processed NN NN O
# for NN NN O
# Western NN NN O
# blotting NN NN O
# at NN NN O
# day NN NN O
# 27 NN NN O
# after NN NN O
# stress NN NN O
# . NN NN O
#
# In NN NN O
# experiment NN NN O
# 2 NN NN O
# , NN NN O
# social NN NN O
# avoidance NN NN O
# tests NN NN O
# were NN NN O
# conducted NN NN O
# , NN NN O
# and NN NN O
# brains NN NN O
# were NN NN O
# processed NN NN O
# for NN NN O
# Western NN NN O
# blotting NN NN O
# at NN NN O
# day NN NN O
# 12 NN NN O
# after NN NN O
# stress NN NN O
# . NN NN O
#
# RESULTS NN NN O
# : NN NN O
# The NN NN O
# results NN NN O
# indicate NN NN O
# decreased NN NN O
# and NN NN O
# increased NN NN O
# locomotion NN NN O
# and NN NN O
# anxiety NN NN O
# behavior NN NN O
# in NN NN O
# all NN NN O
# defeated NN NN O
# mice NN NN O
# . NN NN O
#
# Decrease NN NN O
# in NN NN O
# social NN NN O
# interaction NN NN O
# , NN NN O
# increased NN NN O
# immobility NN NN O
# , NN NN O
# and NN NN O
# impaired NN NN O
# memory NN NN O
# performance NN NN O
# were NN NN O
# only NN NN O
# observed NN NN O
# in NN NN O
# susceptible NN NN O
# mice NN NN O
# . NN NN O
#
# A NN NN O
# decrease NN NN O
# in NN NN O
# the NN NN O
# Chat NN NN O
# level NN NN O
# at NN NN O
# days NN NN O
# 12 NN NN O
# and NN NN O
# 27 NN NN O
# was NN NN O
# noted NN NN O
# in NN NN O
# the NN NN O
# prefrontal NN NN O
# cortex NN NN O
# ( NN NN O
# PFC NN NN O
# ), NN NN O
# amygdala NN NN O
# ( NN NN O
# Amyg NN NN O
# ), NN NN O
# and NN NN O
# dorsal NN NN O
# hippocampus NN NN O
# ( NN NN O
# HIP NN NN O
# ) NN NN O
# in NN NN O
# defeated NN NN O
# mice NN NN O
# . NN NN O
#
# The NN NN O
# expression NN NN O
# levels NN NN O
# of NN NN O
# Grp78 NN NN B-GENE-Y
# and NN NN O
# chop NN NN B-GENE-Y
# measured NN NN O
# on NN NN O
# days NN NN O
# 12 NN NN O
# and NN NN O
# 27 NN NN O
# were NN NN O
# significantly NN NN O
# greater NN NN O
# in NN NN O
# the NN NN O
# Amyg NN NN O
# of NN NN O
# susceptible NN NN O
# mice NN NN O
# . NN NN O
#
# In NN NN O
# the NN NN O
# PFC NN NN O
# and NN NN O
# HIP NN NN O
# , NN NN O
# defeated NN NN O
# mice NN NN O
# displayed NN NN O
# different NN NN O
# patterns NN NN O
# in NN NN O
# the NN NN O
# levels NN NN O
# of NN NN O
# Grp78 NN NN B-GENE-Y
# and NN NN O
# chop NN NN B-GENE-Y
# expressions NN NN O
# measured NN NN O
# on NN NN O
# days NN NN O
# 12 NN NN O
# and NN NN O
#
# 27 NN NN O
# . NN NN O
# CONCLUSIONS NN NN O
# : NN NN O
# The NN NN O
# present NN NN O
# study NN NN O
# demonstrated NN NN O
# that NN NN O
# chronic NN NN O
# social NN NN O
# defeat NN NN O
# stress NN NN O
# in NN NN O
# mice NN NN O
# produces NN NN O
# stress-related NN NN O
# behaviors NN NN O
# . NN NN O
#
# Different NN NN O
# response NN NN O
# patterns NN NN O
# were NN NN O
# noted NN NN O
# for NN NN O
# Grp78 NN NN B-GENE-Y
# and NN NN O
# chop NN NN B-GENE-Y
# expression NN NN O
# among NN NN O
# the NN NN O
# groups NN NN O
# in NN NN O
# terms NN NN O
# of NN NN O
# brain NN NN O
# regions NN NN O
# and NN NN O
# time-course NN NN O
# effects NN NN O
# . NN NN O
#
# -DOCSTART- -X- -23293962- O
#
# Hepatocyte NN NN B-GENE-Y
# growth NN NN I-GENE-Y
# factor NN NN I-GENE-Y
# activator NN NN I-GENE-Y
# inhibitor NN NN I-GENE-Y
# type NN NN I-GENE-Y
# 2 NN NN I-GENE-Y
# ( NN NN O
# HAI-2 NN NN B-GENE-Y
# ) NN NN O
# modulates NN NN O
# hepcidin NN NN B-GENE-Y
# expression NN NN O
# by NN NN O
# inhibiting NN NN O
# the NN NN O
# cell NN NN O
# surface NN NN O
# protease NN NN B-GENE-N
# matriptase-2 NN NN I-GENE-Y
# . NN NN O
#
# Matriptase-2 NN NN B-GENE-Y
# , NN NN O
# a NN NN O
# recently NN NN O
# identified NN NN O
# cell NN NN O
# surface NN NN O
# protease NN NN B-GENE-N
# , NN NN O
# is NN NN O
# the NN NN O
# key NN NN O
# enzyme NN NN O
# of NN NN O
# iron NN NN B-CHEMICAL
# homoeostasis NN NN O
# modulating NN NN O
# the NN NN O
# expression NN NN O
# of NN NN O
# the NN NN O
# liver NN NN O
# peptide NN NN O
# hormone NN NN O
# hepcidin NN NN B-GENE-Y
# . NN NN O
#
# HAI NN NN B-GENE-N
# ( NN NN I-GENE-N
# hepatocyte NN NN I-GENE-N
# growth NN NN I-GENE-N
# factor NN NN I-GENE-N
# activator NN NN I-GENE-N
# inhibitor NN NN I-GENE-N
# ) NN NN I-GENE-N
# types NN NN I-GENE-N
# 1 NN NN I-GENE-N
# and NN NN I-GENE-N
# 2 NN NN I-GENE-N
# ( NN NN O
# HAI-1 NN NN B-GENE-Y
# and NN NN O
# HAI-2 NN NN B-GENE-Y
# respectively NN NN O
# ) NN NN O
# have NN NN O
# been NN NN O
# shown NN NN O
# to NN NN O
# inhibit NN NN O
# the NN NN O
# close NN NN O
# homologue NN NN O
# , NN NN O
# i.e NN NN O
# . NN NN O
# matriptase NN NN B-GENE-N
# . NN NN O
#
# By NN NN O
# co-expressing NN NN O
# matriptase-2 NN NN B-GENE-Y
# and NN NN O
# the NN NN O
# inhibitor NN NN O
# HAI-2 NN NN B-GENE-Y
# we NN NN O
# have NN NN O
# identified NN NN O
# HAI-2 NN NN B-GENE-Y
# displaying NN NN O
# high NN NN O
# inhibitory NN NN O
# potential NN NN O
# against NN NN O
# matriptase-2 NN NN B-GENE-N
# at NN NN O
# the NN NN O
# cell NN NN O
# surface NN NN O
# as NN NN O
# well NN NN O
# as NN NN O
# in NN NN O
# conditioned NN NN O
# medium NN NN O
# . NN NN O
#
# Accordingly NN NN O
# , NN NN O
# complex NN NN O
# formation NN NN O
# between NN NN O
# matriptase-2 NN NN B-GENE-Y
# and NN NN O
# HAI-2 NN NN B-GENE-Y
# was NN NN O
# demonstrated NN NN O
# by NN NN O
# isolation NN NN O
# of NN NN O
# the NN NN O
# complex NN NN O
# via NN NN O
# immobilizing NN NN O
# either NN NN O
# HAI-2 NN NN B-GENE-Y
# or NN NN O
# matriptase-2 NN NN B-GENE-Y
# from NN NN O
# lysates NN NN O
# and NN NN O
# conditioned NN NN O
# medium NN NN O
# of NN NN O
# co-expressing NN NN O
# cells NN NN O
# . NN NN O
#
# Furthermore NN NN O
# , NN NN O
# HAI-2 NN NN B-GENE-Y
# indirectly NN NN O
# influences NN NN O
# the NN NN O
# expression NN NN O
# of NN NN O
# the NN NN O
# hepcidin-encoding NN NN O
# gene NN NN O
# HAMP NN NN B-GENE-Y
# . NN NN O
#
# The NN NN O
# inhibitor NN NN O
# abrogates NN NN O
# the NN NN O
# matriptase-2-mediated NN NN O
# suppression NN NN O
# of NN NN O
# HAMP NN NN B-GENE-Y
# expression NN NN O
# , NN NN O
# presumably NN NN O
# by NN NN O
# inhibiting NN NN O
# the NN NN O
# supposed NN NN O
# potential NN NN O
# of NN NN O
# matriptase-2 NN NN B-GENE-Y
# to NN NN O
# cleave NN NN O
# membrane-bound NN NN O
# HJV NN NN O
#
# ( NN NN O
# haemojuvelin NN NN O
# ). NN NN O
#
# Taken NN NN O
# together NN NN O
# , NN NN O
# the NN NN O
# results NN NN O
# of NN NN O
# the NN NN O
# present NN NN O
# study NN NN O
# have NN NN O
# characterized NN NN O
# HAI-2 NN NN B-GENE-Y
# as NN NN O
# an NN NN O
# inhibitor NN NN O
# of NN NN O
# matriptase-2 NN NN B-GENE-Y
# that NN NN O
# modulates NN NN O
# the NN NN O
# synthesis NN NN O
# of NN NN O
# hepcidin NN NN B-GENE-Y
# and NN NN O
# provides NN NN O
# new NN NN O
# insights NN NN O
# into NN NN O
# the NN NN O
# regulatory NN NN O
# mechanism NN NN O
# of NN NN O
# iron NN NN B-CHEMICAL
# homoeostasis NN NN O
# , NN NN O
# with NN NN O
# clinical NN NN O
# importance NN NN O
# for NN NN O
# a NN NN O
# treatment NN NN O
# of NN NN O
# iron NN NN B-CHEMICAL
# overload NN NN O
# diseases NN NN O
# . NN NN O
#
# -DOCSTART- -X- -7678677- O
#
# Alprenolol NN NN B-CHEMICAL
# and NN NN O
# bromoacetylalprenololmenthane NN NN B-CHEMICAL
# are NN NN O
# competitive NN NN O
# slowly NN NN O
# reversible NN NN O
# antagonists NN NN O
# at NN NN O
# the NN NN O
# beta NN NN B-GENE-Y
# 1-adrenoceptors NN NN I-GENE-Y
# of NN NN O
# rat NN NN O
# left NN NN O
# atria NN NN O
# . NN NN O
#
# We NN NN O
# studied NN NN O
# the NN NN O
# effects NN NN O
# of NN NN O
# alprenolol NN NN B-CHEMICAL
# and NN NN O
# bromoacetylalprenololmenthane NN NN B-CHEMICAL
# ( NN NN O
# BAAM NN NN B-CHEMICAL
# ) NN NN O
# on NN NN O
# rat NN NN O
# left NN NN O
# atria NN NN O
# . NN NN O
#
# Alprenolol NN NN B-CHEMICAL
# and NN NN O
# BAAM NN NN B-CHEMICAL
# at NN NN O
# 10(-7 NN NN O
# ), NN NN O
# 3 NN NN O
# x NN NN O
# 10(-7 NN NN O
# ), NN NN O
# and NN NN O
# 10(-6 NN NN O
# ) NN NN O
# M NN NN O
# inhibited NN NN O
# the NN NN O
# cardiac NN NN O
# stimulation NN NN O
# response NN NN O
# slightly NN NN O
# , NN NN O
# which NN NN O
# is NN NN O
# indicative NN NN O
# of NN NN O
# membrane-stabilizing NN NN O
# activity NN NN O
# independent NN NN O
# of NN NN O
# beta-adrenoceptor NN NN B-GENE-N
# blockade NN NN O
# . NN NN O
#
# This NN NN O
# membrane-stabilizing NN NN O
# activity NN NN O
# was NN NN O
# readily NN NN O
# reversible NN NN O
# . NN NN O
#
# Alprenolol NN NN B-CHEMICAL
# and NN NN O
# BAAM NN NN B-CHEMICAL
# also NN NN O
# caused NN NN O
# surmountable NN NN O
# antagonism NN NN O
# of NN NN O
# isoprenaline NN NN B-CHEMICAL
# responses NN NN O
# , NN NN O
# and NN NN O
# this NN NN O
# beta NN NN B-GENE-Y
# 1-adrenoceptor NN NN I-GENE-Y
# antagonism NN NN O
# was NN NN O
# slowly NN NN O
# reversible NN NN O
# . NN NN O
#
# Inhibition NN NN O
# of NN NN O
# the NN NN O
# isoprenaline NN NN B-CHEMICAL
# responses NN NN O
# with NN NN O
# alprenolol NN NN B-CHEMICAL
# and NN NN O
# BAAM NN NN B-CHEMICAL
# at NN NN O
# 10(-6 NN NN O
# ) NN NN O
# M NN NN O
# was NN NN O
# at NN NN O
# equilibrium NN NN O
# after NN NN O
# 60 NN NN O
# min NN NN O
# , NN NN O
# which NN NN O
# is NN NN O
# indicative NN NN O
# of NN NN O
# reversible NN NN O
# antagonism NN NN O
# . NN NN O
#
# We NN NN O
# conclude NN NN O
# that NN NN O
# alprenolol NN NN B-CHEMICAL
# and NN NN O
# BAAM NN NN B-CHEMICAL
# are NN NN O
# competitive NN NN O
# slowly NN NN O
# reversible NN NN O
# beta NN NN B-GENE-Y
# 1-adrenoceptor NN NN I-GENE-Y
# antagonists NN NN O
# on NN NN O
# rat NN NN O
# left NN NN O
# atria NN NN O
# . NN NN O
#
# -DOCSTART- -X- -16554356- O
#
# Covalent NN NN O
# linkage NN NN O
# of NN NN O
# apolipoprotein NN NN B-GENE-Y
# e NN NN I-GENE-Y
# to NN NN O
# albumin NN NN B-GENE-Y
# nanoparticles NN NN O
# strongly NN NN O
# enhances NN NN O
# drug NN NN O
# transport NN NN O
# into NN NN O
# the NN NN O
# brain NN NN O
# . NN NN O
#
# Drug NN NN O
# delivery NN NN O
# to NN NN O
# the NN NN O
# brain NN NN O
# is NN NN O
# becoming NN NN O
# more NN NN O
# and NN NN O
# more NN NN O
# important NN NN O
# but NN NN O
# is NN NN O
# severely NN NN O
# restricted NN NN O
# by NN NN O
# the NN NN O
# blood-brain NN NN O
# barrier NN NN O
# . NN NN O
#
# Nanoparticles NN NN O
# coated NN NN O
# with NN NN O
# polysorbates NN NN B-CHEMICAL
# have NN NN O
# previously NN NN O
# been NN NN O
# shown NN NN O
# to NN NN O
# enable NN NN O
# the NN NN O
# transport NN NN O
# of NN NN O
# several NN NN O
# drugs NN NN O
# across NN NN O
# the NN NN O
# blood-brain NN NN O
# barrier NN NN O
# , NN NN O
# which NN NN O
# under NN NN O
# normal NN NN O
# circumstances NN NN O
# is NN NN O
# impermeable NN NN O
# to NN NN O
# these NN NN O
# compounds NN NN O
# . NN NN O
#
# Apolipoprotein NN NN B-GENE-Y
# E NN NN I-GENE-Y
# was NN NN O
# suggested NN NN O
# to NN NN O
# mediate NN NN O
# this NN NN O
# drug NN NN O
# transport NN NN O
# across NN NN O
# the NN NN O
# blood-brain NN NN O
# barrier NN NN O
# . NN NN O
#
# In NN NN O
# the NN NN O
# present NN NN O
# study NN NN O
# , NN NN O
# apolipoprotein NN NN B-GENE-Y
# E NN NN I-GENE-Y
# was NN NN O
# coupled NN NN O
# by NN NN O
# chemical NN NN O
# methods NN NN O
# to NN NN O
# nanoparticles NN NN O
# made NN NN O
# of NN NN O
# human NN NN B-GENE-Y
# serum NN NN I-GENE-Y
# albumin NN NN I-GENE-Y
# ( NN NN O
# HSA-NP NN NN O
# ). NN NN O
#
# Loperamide NN NN B-CHEMICAL
# , NN NN O
# which NN NN O
# does NN NN O
# not NN NN O
# cross NN NN O
# the NN NN O
# blood-brain NN NN O
# barrier NN NN O
# but NN NN O
# exerts NN NN O
# antinociceptive NN NN O
# effects NN NN O
# after NN NN O
# direct NN NN O
# injection NN NN O
# into NN NN O
# the NN NN O
# brain NN NN O
# , NN NN O
# was NN NN O
# used NN NN O
# as NN NN O
# model NN NN O
# drug NN NN O
# . NN NN O
#
# Apolipoprotein NN NN B-GENE-Y
# E NN NN I-GENE-Y
# was NN NN O
# chemically NN NN O
# bound NN NN O
# via NN NN O
# linkers NN NN O
# to NN NN O
# loperamide-loaded NN NN O
# HSA-NP NN NN O
# . NN NN O
#
# This NN NN O
# preparation NN NN O
# induced NN NN O
# antinociceptive NN NN O
# effects NN NN O
# in NN NN O
# the NN NN O
# tail-flick NN NN O
# test NN NN O
# in NN NN O
# ICR NN NN O
# mice NN NN O
# after NN NN O
# i.v NN NN O
# . NN NN O
# injection NN NN O
# . NN NN O
#
# In NN NN O
# contrast NN NN O
# , NN NN O
# nanoparticles NN NN O
# linked NN NN O
# to NN NN O
# apolipoprotein NN NN B-GENE-Y
# E NN NN I-GENE-Y
# variants NN NN O
# that NN NN O
# do NN NN O
# not NN NN O
# recognize NN NN O
# lipoprotein NN NN B-GENE-N
# receptors NN NN I-GENE-N
# failed NN NN O
# to NN NN O
# induce NN NN O
# these NN NN O
# effects NN NN O
# . NN NN O
#
# These NN NN O
# results NN NN O
# indicate NN NN O
# that NN NN O
# apolipoprotein NN NN B-GENE-Y
# E NN NN I-GENE-Y
# attached NN NN O
# to NN NN O
# the NN NN O
# surface NN NN O
# of NN NN O
# nanoparticles NN NN O
# facilitates NN NN O
# transport NN NN O
# of NN NN O
# drugs NN NN O
# across NN NN O
# the NN NN O
# blood-brain NN NN O
# barrier NN NN O
# , NN NN O
# probably NN NN O
# after NN NN O
# interaction NN NN O
# with NN NN O
# lipoprotein NN NN B-GENE-N
# receptors NN NN I-GENE-N
# on NN NN O
# the NN NN O
# brain NN NN O
# capillary NN NN O
# endothelial NN NN O
# cell NN NN O
# membranes NN NN O
# . NN NN O
#
# -DOCSTART- -X- -16789740- O
#
# Discovery NN NN O
# and NN NN O
# optimization NN NN O
# of NN NN O
# anthranilic NN NN B-CHEMICAL
# acid NN NN I-CHEMICAL
# sulfonamides NN NN I-CHEMICAL
# as NN NN O
# inhibitors NN NN O
# of NN NN O
# methionine NN NN I-GENE-Y
# aminopeptidase-2 NN NN I-GENE-Y
# : NN NN O
# a NN NN O
# structural NN NN O
# basis NN NN O
# for NN NN O
# the NN NN O
# reduction NN NN O
# of NN NN O
# albumin NN NN B-GENE-Y
# binding NN NN O
# . NN NN O
#
# Methionine NN NN I-GENE-Y
# aminopeptidase-2 NN NN I-GENE-Y
# ( NN NN O
# MetAP2 NN NN B-GENE-Y
# ) NN NN O
# is NN NN O
# a NN NN O
# novel NN NN O
# target NN NN O
# for NN NN O
# cancer NN NN O
# therapy NN NN O
# . NN NN O
#
# As NN NN O
# part NN NN O
# of NN NN O
# an NN NN O
# effort NN NN O
# to NN NN O
# discover NN NN O
# orally NN NN O
# active NN NN O
# reversible NN NN O
# inhibitors NN NN O
# of NN NN O
# MetAP2 NN NN B-GENE-Y
# , NN NN O
# a NN NN O
# series NN NN O
# of NN NN O
# anthranilic NN NN B-CHEMICAL
# acid NN NN I-CHEMICAL
# sulfonamides NN NN I-CHEMICAL
# with NN NN O
# micromolar NN NN O
# affinities NN NN O
# for NN NN O
# human NN NN B-GENE-Y
# MetAP2 NN NN I-GENE-Y
# were NN NN O
# identified NN NN O
# using NN NN O
# affinity NN NN O
# selection NN NN O
# by NN NN O
# mass NN NN O
# spectrometry NN NN O
# ( NN NN O
# ASMS NN NN O
# ) NN NN O
# screening NN NN O
# . NN NN O
#
# These NN NN O
# micromolar NN NN O
# hits NN NN O
# were NN NN O
# rapidly NN NN O
# improved NN NN O
# to NN NN O
# nanomolar NN NN O
# leads NN NN O
# on NN NN O
# the NN NN O
# basis NN NN O
# of NN NN O
# insights NN NN O
# from NN NN O
# protein NN NN O
# crystallography NN NN O
# ; NN NN O
#
# however NN NN O
# , NN NN O
# the NN NN O
# compounds NN NN O
# displayed NN NN O
# extensive NN NN O
# binding NN NN O
# to NN NN O
# human NN NN B-GENE-Y
# serum NN NN I-GENE-Y
# albumin NN NN I-GENE-Y
# and NN NN O
# had NN NN O
# limited NN NN O
# activity NN NN O
# in NN NN O
# cellular NN NN O
# assays NN NN O
# . NN NN O
#
# Modifications NN NN O
# based NN NN O
# on NN NN O
# structural NN NN O
# information NN NN O
# on NN NN O
# the NN NN O
# binding NN NN O
# of NN NN O
# lead NN NN O
# compounds NN NN O
# to NN NN O
# both NN NN O
# MetAP2 NN NN B-GENE-Y
# and NN NN O
# domain NN NN B-GENE-N
# III NN NN I-GENE-N
# of NN NN I-GENE-N
# albumin NN NN I-GENE-N
# allowed NN NN O
# the NN NN O
# identification NN NN O
# of NN NN O
# compounds NN NN O
# with NN NN O
# significant NN NN O
# improvements NN NN O
# in NN NN O
# both NN NN O
# parameters NN NN O
# , NN NN O
# which NN NN O
# showed NN NN O
# good NN NN O
# cellular NN NN O
# activity NN NN O
# in NN NN O
# both NN NN O
# proliferation NN NN O
# and NN NN O
# methionine NN NN B-CHEMICAL
# processing NN NN O
# assays NN NN O
# . NN NN O
#
# -DOCSTART- -X- -7526860- O
#
# Keratinocyte NN NN B-GENE-Y
# growth NN NN I-GENE-Y
# factor NN NN I-GENE-Y
# and NN NN O
# acidic NN NN B-GENE-Y
# fibroblast NN NN I-GENE-Y
# growth NN NN I-GENE-Y
# factor NN NN I-GENE-Y
# are NN NN O
# mitogens NN NN O
# for NN NN O
# primary NN NN O
# cultures NN NN O
# of NN NN O
# mammary NN NN O
# epithelium NN NN O
# . NN NN O
#
# Mammary NN NN O
# epithelial NN NN O
# cells NN NN O
# derived NN NN O
# from NN NN O
# the NN NN O
# entire NN NN O
# mammary NN NN O
# parenchyma NN NN O
# or NN NN O
# only NN NN O
# end NN NN O
# buds NN NN O
# were NN NN O
# isolated NN NN O
# by NN NN O
# collagenase NN NN B-GENE-N
# digestion NN NN O
# of NN NN O
# mammary NN NN O
# glands NN NN O
# from NN NN O
# virgin NN NN O
# mice NN NN O
# . NN NN O
#
# Cells NN NN O
# were NN NN O
# cultured NN NN O
# within NN NN O
# collagen NN NN O
# gels NN NN O
# in NN NN O
# serum-free NN NN O
# medium NN NN O
# containing NN NN O
# insulin NN NN B-GENE-Y
# . NN NN O
#
# Keratinocyte NN NN B-GENE-Y
# growth NN NN I-GENE-Y
# factor NN NN I-GENE-Y
# ( NN NN O
# KGF NN NN B-GENE-Y
# or NN NN O
# FGF-7 NN NN B-GENE-Y
# ) NN NN O
# and NN NN O
# acidic NN NN B-GENE-Y
# fibroblast NN NN I-GENE-Y
# growth NN NN I-GENE-Y
# factor NN NN I-GENE-Y
# ( NN NN O
# aFGF NN NN B-GENE-Y
# or NN NN O
# FGF-1 NN NN B-GENE-Y
# ) NN NN O
# stimulated NN NN O
# multifold NN NN O
# proliferation NN NN O
# when NN NN O
# added NN NN O
# alone NN NN O
# to NN NN O
# this NN NN O
# medium NN NN O
# . NN NN O
#
# Growth NN NN O
# occurred NN NN O
# as NN NN O
# three-dimensional NN NN O
# colonies NN NN O
# within NN NN O
# the NN NN O
# collagen NN NN B-GENE-N
# gel NN NN O
# matrix NN NN O
# . NN NN O
#
# KGF NN NN B-GENE-Y
# stimulated NN NN O
# growth NN NN O
# was NN NN O
# unaffected NN NN O
# by NN NN O
# adding NN NN O
# heparin NN NN O
# . NN NN O
#
# Conversely NN NN O
# , NN NN O
# multifold NN NN O
# growth NN NN O
# stimulation NN NN O
# by NN NN O
# acidic NN NN B-GENE-Y
# FGF NN NN I-GENE-Y
# required NN NN O
# heparin NN NN O
# . NN NN O
#
# Since NN NN O
# end NN NN O
# buds NN NN O
# are NN NN O
# the NN NN O
# actively NN NN O
# proliferating NN NN O
# cell NN NN O
# population NN NN O
# of NN NN O
# ductal NN NN O
# glands NN NN O
# , NN NN O
# organ NN NN O
# cultures NN NN O
# of NN NN O
# these NN NN O
# structures NN NN O
# were NN NN O
# prepared NN NN O
# . NN NN O
#
# KGF NN NN B-GENE-Y
# stimulated NN NN O
# 3H-thymidine NN NN B-CHEMICAL
# incorporation NN NN O
# in NN NN O
# these NN NN O
# end NN NN O
# buds NN NN O
# in NN NN O
# the NN NN O
# absence NN NN O
# and NN NN O
# presence NN NN O
# of NN NN O
# epidermal NN NN B-GENE-Y
# growth NN NN I-GENE-Y
# factor NN NN I-GENE-Y
# . NN NN O
#
# These NN NN O
# data NN NN O
# suggest NN NN O
# that NN NN O
# acidic NN NN B-GENE-Y
# FGF NN NN I-GENE-Y
# and NN NN O
# KGF NN NN B-GENE-Y
# may NN NN O
# represent NN NN O
# in NN NN O
# vivo NN NN O
# stromal NN NN O
# factors NN NN O
# capable NN NN O
# of NN NN O
# regulating NN NN O
# mammary NN NN O
# gland NN NN O
# development NN NN O
# . NN NN O
#
# -DOCSTART- -X- -17199504- O
#
# Configuration NN NN O
# of NN NN O
# a NN NN O
# scintillation NN NN O
# proximity NN NN O
# assay NN NN O
# for NN NN O
# the NN NN O
# activity NN NN O
# assessment NN NN O
# of NN NN O
# recombinant NN NN O
# human NN NN B-GENE-Y
# adenine NN NN I-GENE-Y
# phosphoribosyltransferase NN NN I-GENE-Y
# . NN NN O
#
# Adenine NN NN I-GENE-Y
# phosphoribosyltransferase NN NN I-GENE-Y
# plays NN NN O
# a NN NN O
# role NN NN O
# in NN NN O
# purine NN NN B-CHEMICAL
# salvage NN NN O
# by NN NN O
# catalyzing NN NN O
# the NN NN O
# direct NN NN O
# conversion NN NN O
# of NN NN O
# adenine NN NN B-CHEMICAL
# to NN NN O
# adenosine NN NN B-CHEMICAL
# monophosphate NN NN I-CHEMICAL
# . NN NN O
#
# The NN NN O
# involvement NN NN O
# of NN NN O
# the NN NN O
# purine NN NN B-CHEMICAL
# salvage NN NN O
# pathway NN NN O
# in NN NN O
# tumor NN NN O
# proliferation NN NN O
# and NN NN O
# angiogenesis NN NN O
# makes NN NN O
# adenine NN NN I-GENE-Y
# phosphoribosyltransferase NN NN I-GENE-Y
# a NN NN O
# potential NN NN O
# target NN NN O
# for NN NN O
# oncology NN NN O
# drug NN NN O
# discovery NN NN O
# . NN NN O
#
# We NN NN O
# have NN NN O
# expressed NN NN O
# and NN NN O
# characterized NN NN O
# recombinant NN NN O
# , NN NN O
# N-terminally NN NN O
# His-tagged NN NN O
# human NN NN B-GENE-Y
# adenine NN NN I-GENE-Y
# phosphoribosyltransferase NN NN I-GENE-Y
# . NN NN O
#
# Two NN NN O
# assay NN NN O
# formats NN NN O
# were NN NN O
# assessed NN NN O
# for NN NN O
# use NN NN O
# in NN NN O
# a NN NN O
# high NN NN O
# throughput NN NN O
# screen NN NN O
# : NN NN O
# a NN NN O
# spectrophotometric-based NN NN O
# enzyme-coupled NN NN O
# assay NN NN O
# system NN NN O
# and NN NN O
# a NN NN O
# radiometric NN NN O
# ionic NN NN O
# capture NN NN O
# scintillation NN NN O
# proximity NN NN O
# bead NN NN O
# assay NN NN O
# format NN NN O
# . NN NN O
#
# Ultimately NN NN O
# , NN NN O
# the NN NN O
# scintillation NN NN O
# proximity NN NN O
# assay NN NN O
# format NN NN O
# was NN NN O
# chosen NN NN O
# because NN NN O
# of NN NN O
# automated NN NN O
# screening NN NN O
# compatibility NN NN O
# limitations NN NN O
# of NN NN O
# the NN NN O
# coupled NN NN O
# assay NN NN O
# . NN NN O
#
# We NN NN O
# describe NN NN O
# here NN NN O
# the NN NN O
# biochemical NN NN O
# characterization NN NN O
# of NN NN O
# adenine NN NN I-GENE-Y
# phosphoribosyltransferase NN NN I-GENE-Y
# and NN NN O
# the NN NN O
# development NN NN O
# of NN NN O
# a NN NN O
# robust NN NN O
# , NN NN O
# homogeneous NN NN O
# , NN NN O
# 384-well NN NN O
# assay NN NN O
# suitable NN NN O
# for NN NN O
# high NN NN O
# throughput NN NN O
# screening NN NN O
# . NN NN O
#
# -DOCSTART- -X- -16437532- O
#
# Cholinesterase NN NN B-GENE-Y
# inhibitors NN NN O
# for NN NN O
# Alzheimer's NN NN O
# disease NN NN O
# . NN NN O
#
# BACKGROUND NN NN O
# : NN NN O
# Since NN NN O
# the NN NN O
# introduction NN NN O
# of NN NN O
# the NN NN O
# first NN NN O
# cholinesterase NN NN B-GENE-Y
# inhibitor NN NN O
# ( NN NN O
# ChEI NN NN O
# ) NN NN O
# in NN NN O
# 1997 NN NN O
# , NN NN O
# most NN NN O
# clinicians NN NN O
# and NN NN O
# probably NN NN O
# most NN NN O
# patients NN NN O
# would NN NN O
# consider NN NN O
# the NN NN O
# cholinergic NN NN O
# drugs NN NN O
# , NN NN O
# donepezil NN NN B-CHEMICAL
# , NN NN O
# galantamine NN NN B-CHEMICAL
# and NN NN O
# rivastigmine NN NN B-CHEMICAL
# , NN NN O
# to NN NN O
# be NN NN O
# the NN NN O
# first NN NN O
# line NN NN O
# pharmacotherapy NN NN O
# for NN NN O
# mild NN NN O
# to NN NN O
# moderate NN NN O
# Alzheimer's NN NN O
# disease.The NN NN O
# drugs NN NN O
# have NN NN O
# slightly NN NN O
# different NN NN O
# pharmacological NN NN O
# properties NN NN O
# , NN NN O
# but NN NN O
# they NN NN O
# all NN NN O
# work NN NN O
# by NN NN O
# inhibiting NN NN O
# the NN NN O
# breakdown NN NN O
# of NN NN O
# acetylcholine NN NN B-CHEMICAL
# , NN NN O
# an NN NN O
# important NN NN O
# neurotransmitter NN NN O
# associated NN NN O
# with NN NN O
# memory NN NN O
# , NN NN O
# by NN NN O
# blocking NN NN O
# the NN NN O
# enzyme NN NN O
# acetylcholinesterase NN NN B-GENE-Y
# . NN NN O
#
# The NN NN O
# most NN NN O
# that NN NN O
# these NN NN O
# drugs NN NN O
# could NN NN O
# achieve NN NN O
# is NN NN O
# to NN NN O
# modify NN NN O
# the NN NN O
# manifestations NN NN O
# of NN NN O
# Alzheimer's NN NN O
# disease NN NN O
# . NN NN O
#
# Cochrane NN NN O
# reviews NN NN O
# of NN NN O
# each NN NN O
# ChEI NN NN O
# for NN NN O
# Alzheimer's NN NN O
# disease NN NN O
# have NN NN O
# been NN NN O
# completed NN NN O
# ( NN NN O
# Birks NN NN O
# 2005 NN NN O
# , NN NN O
# Birks NN NN O
# 2005b NN NN O
# and NN NN O
# Loy NN NN O
# 2005 NN NN O
# ). NN NN O
#
# Despite NN NN O
# the NN NN O
# evidence NN NN O
# from NN NN O
# the NN NN O
# clinical NN NN O
# studies NN NN O
# and NN NN O
# the NN NN O
# intervening NN NN O
# clinical NN NN O
# experience NN NN O
# the NN NN O
# debate NN NN O
# on NN NN O
# whether NN NN O
# ChEIs NN NN O
# are NN NN O
# effective NN NN O
# continues NN NN O
# . NN NN O
#
# OBJECTIVES NN NN O
# : NN NN O
# To NN NN O
# assess NN NN O
# the NN NN O
# effects NN NN O
# of NN NN O
# donepezil NN NN B-CHEMICAL
# , NN NN O
# galantamine NN NN B-CHEMICAL
# and NN NN O
# rivastigmine NN NN B-CHEMICAL
# in NN NN O
# people NN NN O
# with NN NN O
# mild NN NN O
# , NN NN O
# moderate NN NN O
# or NN NN O
# severe NN NN O
# dementia NN NN O
# due NN NN O
# to NN NN O
# Alzheimer's NN NN O
# disease NN NN O
# . NN NN O
#
# SEARCH NN NN O
# STRATEGY NN NN O
# : NN NN O
# The NN NN O
# Cochrane NN NN O
# Dementia NN NN O
# and NN NN O
# Cognitive NN NN O
# Improvement NN NN O
# Group's NN NN O
# Specialized NN NN O
# Register NN NN O
# was NN NN O
# searched NN NN O
# using NN NN O
# the NN NN O
# terms NN NN O
# ' NN NN O
# donepezil NN NN B-CHEMICAL
# ', NN NN O
# ' NN NN O
# E2020 NN NN B-CHEMICAL
# ' NN NN O
# , NN NN O
# ' NN NN O
# Aricept NN NN B-CHEMICAL
# ' NN NN O
# , NN NN O
# galanthamin NN NN B-CHEMICAL
# * NN NN O
# galantamin NN NN B-CHEMICAL
# * NN NN O
# reminyl NN NN B-CHEMICAL
# , NN NN O
# rivastigmine NN NN B-CHEMICAL
# , NN NN O
# exelon NN NN B-CHEMICAL
# , NN NN O
# " NN NN O
# ENA NN NN B-CHEMICAL
# 713 NN NN I-CHEMICAL
# " NN NN O
# and NN NN O
# ENA-713 NN NN B-CHEMICAL
# on NN NN O
# 12 NN NN O
# June NN NN O
# 2005 NN NN O
# . NN NN O
#
# This NN NN O
# Register NN NN O
# contains NN NN O
# up-to-date NN NN O
# records NN NN O
# of NN NN O
# all NN NN O
# major NN NN O
# health NN NN O
# care NN NN O
# databases NN NN O
# and NN NN O
# many NN NN O
# ongoing NN NN O
# trial NN NN O
# databases NN NN O
# . NN NN O
#
# SELECTION NN NN O
# CRITERIA NN NN O
# : NN NN O
# All NN NN O
# unconfounded NN NN O
# , NN NN O
# blinded NN NN O
# , NN NN O
# randomized NN NN O
# trials NN NN O
# in NN NN O
# which NN NN O
# treatment NN NN O
# with NN NN O
# a NN NN O
# ChEI NN NN O
# was NN NN O
# compared NN NN O
# with NN NN O
# placebo NN NN O
# or NN NN O
# another NN NN O
# ChEI NN NN O
# for NN NN O
# patients NN NN O
# with NN NN O
# mild NN NN O
# , NN NN O
# moderate NN NN O
# or NN NN O
# severe NN NN O
# dementia NN NN O
# due NN NN O
# to NN NN O
# Alzheimer's NN NN O
# disease NN NN O
# . NN NN O
#
# DATA NN NN O
# COLLECTION NN NN O
# AND NN NN O
# ANALYSIS NN NN O
# : NN NN O
# Data NN NN O
# were NN NN O
# extracted NN NN O
# by NN NN O
# one NN NN O
# reviewer NN NN O
# ( NN NN O
# JSB NN NN O
# ), NN NN O
# pooled NN NN O
# where NN NN O
# appropriate NN NN O
# and NN NN O
# possible NN NN O
# , NN NN O
# and NN NN O
# the NN NN O
# pooled NN NN O
# treatment NN NN O
# effects NN NN O
# , NN NN O
# or NN NN O
# the NN NN O
# risks NN NN O
# and NN NN O
# benefits NN NN O
# of NN NN O
# treatment NN NN O
# estimated NN NN O
# . NN NN O
#
# MAIN NN NN O
# RESULTS NN NN O
# : NN NN O
# The NN NN O
# results NN NN O
# of NN NN O
# 13 NN NN O
# randomized NN NN O
# , NN NN O
# double NN NN O
# blind NN NN O
# , NN NN O
# placebo NN NN O
# controlled NN NN O
# trials NN NN O
# demonstrate NN NN O
# that NN NN O
# treatment NN NN O
# for NN NN O
# periods NN NN O
# of NN NN O
# 6 NN NN O
# months NN NN O
# and NN NN O
# one NN NN O
# year NN NN O
# , NN NN O
# with NN NN O
# donepezil NN NN B-CHEMICAL
# , NN NN O
# galantamine NN NN B-CHEMICAL
# or NN NN O
# rivastigmine NN NN B-CHEMICAL
# at NN NN O
# the NN NN O
# recommended NN NN O
# dose NN NN O
# for NN NN O
# people NN NN O
# with NN NN O
# mild NN NN O
# , NN NN O
# moderate NN NN O
# or NN NN O
# severe NN NN O
# dementia NN NN O
# due NN NN O
# to NN NN O
# Alzheimer's NN NN O
# disease NN NN O
# produced NN NN O
# improvements NN NN O
# in NN NN O
# cognitive NN NN O
# function NN NN O
# , NN NN O
# on NN NN O
# average NN NN O
# - NN NN O
# 2.7 NN NN O
# points NN NN O
# ( NN NN O
# 95%CI NN NN O
# - NN NN O
# 3.0 NN NN O
# to NN NN O
# - NN NN O
# 2.3 NN NN O
# ), NN NN O
# in NN NN O
# the NN NN O
# midrange NN NN O
# of NN NN O
# the NN NN O
# 70 NN NN O
# point NN NN O
# ADAS-Cog NN NN O
# Scale NN NN O
# . NN NN O
#
# Study NN NN O
# clinicians NN NN O
# blind NN NN O
# to NN NN O
# other NN NN O
# measures NN NN O
# rated NN NN O
# global NN NN O
# clinical NN NN O
# state NN NN O
# more NN NN O
# positively NN NN O
# in NN NN O
# treated NN NN O
# patients NN NN O
# . NN NN O
#
# Benefits NN NN O
# of NN NN O
# treatment NN NN O
# were NN NN O
# also NN NN O
# seen NN NN O
# on NN NN O
# measures NN NN O
# of NN NN O
# activities NN NN O
# of NN NN O
# daily NN NN O
# living NN NN O
# and NN NN O
# behaviour NN NN O
# . NN NN O
#
# None NN NN O
# of NN NN O
# these NN NN O
# treatment NN NN O
# effects NN NN O
# are NN NN O
# large NN NN O
# . NN NN O
#
# There NN NN O
# is NN NN O
# nothing NN NN O
# to NN NN O
# suggest NN NN O
# the NN NN O
# effects NN NN O
# are NN NN O
# less NN NN O
# for NN NN O
# patients NN NN O
# with NN NN O
# severe NN NN O
# dementia NN NN O
# or NN NN O
# mild NN NN O
# dementia NN NN O
# , NN NN O
# although NN NN O
# there NN NN O
# is NN NN O
# very NN NN O
# little NN NN O
# evidence NN NN O
# for NN NN O
# other NN NN O
# than NN NN O
# mild NN NN O
# to NN NN O
# moderate NN NN O
# dementia.More NN NN O
# patients NN NN O
# leave NN NN O
# ChEI NN NN O
# treatment NN NN O
# groups NN NN O
# , NN NN O
# approximately NN NN O
# 29 NN NN O
# % NN NN O
# , NN NN O
# on NN NN O
# account NN NN O
# of NN NN O
# adverse NN NN O
# events NN NN O
# than NN NN O
# leave NN NN O
# the NN NN O
# placebo NN NN O
# groups NN NN O
# ( NN NN O
# 18% NN NN O
# ). NN NN O
#
# There NN NN O
# is NN NN O
# evidence NN NN O
# of NN NN O
# more NN NN O
# adverse NN NN O
# events NN NN O
# in NN NN O
# total NN NN O
# in NN NN O
# the NN NN O
# patients NN NN O
# treated NN NN O
# with NN NN O
# a NN NN O
# ChEI NN NN O
# than NN NN O
# with NN NN O
# placebo NN NN O
# . NN NN O
#
# Although NN NN O
# many NN NN O
# types NN NN O
# of NN NN O
# adverse NN NN O
# event NN NN O
# were NN NN O
# reported NN NN O
# , NN NN O
# nausea NN NN O
# , NN NN O
# vomiting NN NN O
# , NN NN O
# diarrhoea NN NN O
# , NN NN O
# were NN NN O
# significantly NN NN O
# more NN NN O
# frequent NN NN O
# in NN NN O
# the NN NN O
# ChEI NN NN O
# groups NN NN O
# than NN NN O
# in NN NN O
# placebo NN NN O
# . NN NN O
#
# There NN NN O
# are NN NN O
# four NN NN O
# studies NN NN O
# , NN NN O
# all NN NN O
# supported NN NN O
# by NN NN O
# one NN NN O
# of NN NN O
# the NN NN O
# pharmaceutical NN NN O
# companies NN NN O
# , NN NN O
# in NN NN O
# which NN NN O
# two NN NN O
# ChEIs NN NN O
# were NN NN O
# compared NN NN O
# , NN NN O
# two NN NN O
# studies NN NN O
# of NN NN O
# donepezil NN NN B-CHEMICAL
# compared NN NN O
# with NN NN O
# galantamine NN NN B-CHEMICAL
# , NN NN O
# and NN NN O
# two NN NN O
# of NN NN O
# donepezil NN NN B-CHEMICAL
# compared NN NN O
# with NN NN O
# rivastigmine NN NN B-CHEMICAL
# . NN NN O
#
# In NN NN O
# three NN NN O
# studies NN NN O
# the NN NN O
# patients NN NN O
# were NN NN O
# not NN NN O
# blinded NN NN O
# to NN NN O
# treatment NN NN O
# , NN NN O
# only NN NN O
# the NN NN O
# fourth NN NN O
# , NN NN O
# DON NN NN O
# vs NN NN O
# RIV/Bullock NN NN O
# is NN NN O
# double NN NN O
# blind NN NN O
# . NN NN O
#
# Two NN NN O
# of NN NN O
# the NN NN O
# studies NN NN O
# provide NN NN O
# little NN NN O
# evidence NN NN O
# , NN NN O
# they NN NN O
# are NN NN O
# of NN NN O
# 12 NN NN O
# weeks NN NN O
# duration NN NN O
# , NN NN O
# which NN NN O
# is NN NN O
# barely NN NN O
# long NN NN O
# enough NN NN O
# to NN NN O
# complete NN NN O
# the NN NN O
# drug NN NN O
# titration NN NN O
# . NN NN O
#
# There NN NN O
# is NN NN O
# no NN NN O
# evidence NN NN O
# from NN NN O
# DON NN NN O
# vs NN NN O
# GAL/Wilcock NN NN O
# of NN NN O
# a NN NN O
# treatment NN NN O
# difference NN NN O
# between NN NN O
# donepezil NN NN B-CHEMICAL
# and NN NN O
# galantamine NN NN B-CHEMICAL
# at NN NN O
# 52 NN NN O
# weeks NN NN O
# for NN NN O
# cognition NN NN O
# , NN NN O
# activities NN NN O
# of NN NN O
# daily NN NN O
# living NN NN O
# , NN NN O
# the NN NN O
# numbers NN NN O
# who NN NN O
# leave NN NN O
# the NN NN O
# trial NN NN O
# before NN NN O
# the NN NN O
# end NN NN O
# of NN NN O
# treatment NN NN O
# , NN NN O
# the NN NN O
# number NN NN O
# who NN NN O
# suffer NN NN O
# any NN NN O
# adverse NN NN O
# event NN NN O
# , NN NN O
# or NN NN O
# any NN NN O
# specific NN NN O
# adverse NN NN O
# event NN NN O
# . NN NN O
#
# There NN NN O
# is NN NN O
# no NN NN O
# evidence NN NN O
# from NN NN O
# DON NN NN O
# vs NN NN O
# RIV/Bullock NN NN O
# of NN NN O
# a NN NN O
# difference NN NN O
# between NN NN O
# donepezil NN NN B-CHEMICAL
# and NN NN O
# rivastigmine NN NN B-CHEMICAL
# for NN NN O
# cognitive NN NN O
# function NN NN O
# , NN NN O
# activities NN NN O
# of NN NN O
# daily NN NN O
# living NN NN O
# and NN NN O
# behavioural NN NN O
# disturbance NN NN O
# at NN NN O
# two NN NN O
# years NN NN O
# . NN NN O
#
# Fewer NN NN O
# patients NN NN O
# suffer NN NN O
# adverse NN NN O
# events NN NN O
# on NN NN O
# donepezil NN NN B-CHEMICAL
# than NN NN O
# rivastigmine NN NN B-CHEMICAL
# . NN NN O
#
# AUTHORS NN NN O
# ' NN NN O
# CONCLUSIONS NN NN O
# : NN NN O
# The NN NN O
# three NN NN O
# cholinesterase NN NN B-GENE-Y
# inhibitors NN NN O
# are NN NN O
# efficacious NN NN O
# for NN NN O
# mild NN NN O
# to NN NN O
# moderate NN NN O
# Alzheimer's NN NN O
# disease NN NN O
# . NN NN O
#
# It NN NN O
# is NN NN O
# not NN NN O
# possible NN NN O
# to NN NN O
# identify NN NN O
# those NN NN O
# who NN NN O
# will NN NN O
# respond NN NN O
# to NN NN O
# treatment NN NN O
# prior NN NN O
# to NN NN O
# treatment NN NN O
# . NN NN O
#
# There NN NN O
# is NN NN O
# no NN NN O
# evidence NN NN O
# that NN NN O
# treatment NN NN O
# with NN NN O
# a NN NN O
# ChEI NN NN O
# is NN NN O
# not NN NN O
# cost NN NN O
# effective NN NN O
# . NN NN O
#
# Despite NN NN O
# the NN NN O
# slight NN NN O
# variations NN NN O
# in NN NN O
# the NN NN O
# mode NN NN O
# of NN NN O
# action NN NN O
# of NN NN O
# the NN NN O
# three NN NN O
# cholinesterase NN NN B-GENE-Y
# inhibitors NN NN O
# there NN NN O
# is NN NN O
# no NN NN O
# evidence NN NN O
# of NN NN O
# any NN NN O
# differences NN NN O
# between NN NN O
# them NN NN O
# with NN NN O
# respect NN NN O
# to NN NN O
# efficacy NN NN O
# . NN NN O
#
# There NN NN O
# appears NN NN O
# to NN NN O
# be NN NN O
# less NN NN O
# adverse NN NN O
# effects NN NN O
# associated NN NN O
# with NN NN O
# donepezil NN NN B-CHEMICAL
# compared NN NN O
# with NN NN O
# rivastigmine NN NN B-CHEMICAL
# . NN NN O
#
# It NN NN O
# may NN NN O
# be NN NN O
# that NN NN O
# galantamine NN NN B-CHEMICAL
# and NN NN O
# rivastigmine NN NN B-CHEMICAL
# match NN NN O
# donepezil NN NN B-CHEMICAL
# in NN NN O
# tolerability NN NN O
# if NN NN O
# a NN NN O
# careful NN NN O
# and NN NN O
# gradual NN NN O
# titration NN NN O
# routine NN NN O
# over NN NN O
# more NN NN O
# than NN NN O
# three NN NN O
# months NN NN O
# is NN NN O
# used NN NN O
# . NN NN O
#
# Titration NN NN O
# with NN NN O
# donepezil NN NN B-CHEMICAL
# is NN NN O
# more NN NN O
# straightforward NN NN O
# and NN NN O
# the NN NN O
# lower NN NN O
# dose NN NN O
# may NN NN O
# be NN NN O
# worth NN NN O
# consideration NN NN O
# . NN NN O
#
# -DOCSTART- -X- -11716850- O
#
# The NN NN O
# effects NN NN O
# of NN NN O
# mitiglinide NN NN B-CHEMICAL
# ( NN NN O
# KAD-1229 NN NN B-CHEMICAL
# ), NN NN O
# a NN NN O
# new NN NN O
# anti-diabetic NN NN O
# drug NN NN O
# , NN NN O
# on NN NN O
# ATP-sensitive NN NN B-GENE-N
# K+ NN NN I-GENE-N
# channels NN NN I-GENE-N
# and NN NN O
# insulin NN NN B-GENE-Y
# secretion NN NN O
# : NN NN O
# comparison NN NN O
# with NN NN O
# the NN NN O
# sulfonylureas NN NN B-CHEMICAL
# and NN NN O
# nateglinide NN NN B-CHEMICAL
# . NN NN O
#
# Mitiglinide NN NN B-CHEMICAL
# ( NN NN O
# KAD-1229 NN NN B-CHEMICAL
# ), NN NN O
# a NN NN O
# new NN NN O
# anti-diabetic NN NN O
# drug NN NN O
# , NN NN O
# is NN NN O
# thought NN NN O
# to NN NN O
# stimulate NN NN O
# insulin NN NN B-GENE-Y
# secretion NN NN O
# by NN NN O
# closing NN NN O
# the NN NN O
# ATP-sensitive NN NN B-GENE-N
# K+ NN NN I-GENE-N
# ( NN NN I-GENE-N
# K(ATP NN NN I-GENE-N
# )) NN NN I-GENE-N
# channels NN NN I-GENE-N
# in NN NN O
# pancreatic NN NN O
# beta-cells NN NN O
# . NN NN O
#
# However NN NN O
# , NN NN O
# its NN NN O
# selectivity NN NN O
# for NN NN O
# the NN NN O
# various NN NN O
# K(ATP NN NN B-GENE-N
# ) NN NN I-GENE-N
# channels NN NN I-GENE-N
# is NN NN O
# not NN NN O
# known NN NN O
# . NN NN O
#
# In NN NN O
# this NN NN O
# study NN NN O
# , NN NN O
# we NN NN O
# examined NN NN O
# the NN NN O
# effects NN NN O
# of NN NN O
# mitiglinide NN NN B-CHEMICAL
# on NN NN O
# various NN NN O
# cloned NN NN O
# K(ATP NN NN B-GENE-N
# ) NN NN I-GENE-N
# channels NN NN I-GENE-N
# ( NN NN O
# Kir6.2/SUR1 NN NN O
# , NN NN O
# Kir6.2/SUR2A NN NN O
# , NN NN O
# and NN NN O
# Kir6.2/SUR2B NN NN O
# ) NN NN O
# reconstituted NN NN O
# in NN NN O
# COS-1 NN NN O
# cells NN NN O
# , NN NN O
# and NN NN O
# compared NN NN O
# them NN NN O
# to NN NN O
# another NN NN O
# meglitinide-related NN NN O
# compound NN NN O
# , NN NN O
# nateglinide NN NN B-CHEMICAL
# . NN NN O
#
# Patch-clamp NN NN O
# analysis NN NN O
# using NN NN O
# inside-out NN NN O
# recording NN NN O
# configuration NN NN O
# showed NN NN O
# that NN NN O
# mitiglinide NN NN B-CHEMICAL
# inhibits NN NN O
# the NN NN O
# Kir6.2/SUR1 NN NN O
# channel NN NN O
# currents NN NN O
# in NN NN O
# a NN NN O
# dose-dependent NN NN O
# manner NN NN O
# ( NN NN O
# IC50 NN NN O
# value NN NN O
# , NN NN O
# 100 NN NN O
# nM NN NN O
# ) NN NN O
# but NN NN O
# does NN NN O
# not NN NN O
# significantly NN NN O
# inhibit NN NN O
# either NN NN O
# Kir6.2/SUR2A NN NN O
# or NN NN O
# Kir6.2/SUR2B NN NN O
# channel NN NN O
# currents NN NN O
# even NN NN O
# at NN NN O
# high NN NN O
# doses NN NN O
# ( NN NN O
# more NN NN O
# than NN NN O
# 10 NN NN O
# microM NN NN O
# ). NN NN O
#
# Nateglinide NN NN B-CHEMICAL
# inhibits NN NN O
# Kir6.2/SUR1 NN NN O
# and NN NN O
# Kir6.2/SUR2B NN NN O
# channels NN NN O
# at NN NN O
# 100 NN NN O
# nM NN NN O
# , NN NN O
# and NN NN O
# inhibits NN NN O
# Kir6.2/SUR2A NN NN O
# channels NN NN O
# at NN NN O
# high NN NN O
# concentrations NN NN O
# ( NN NN O
# 1 NN NN O
# microM NN NN O
# ). NN NN O
#
# Binding NN NN O
# experiments NN NN O
# on NN NN O
# mitiglinide NN NN B-CHEMICAL
# , NN NN O
# nateglinide NN NN B-CHEMICAL
# , NN NN O
# and NN NN O
# repaglinide NN NN B-CHEMICAL
# to NN NN O
# SUR1 NN NN B-GENE-Y
# expressed NN NN O
# in NN NN O
# COS-1 NN NN O
# cells NN NN O
# revealed NN NN O
# that NN NN O
# they NN NN O
# inhibit NN NN O
# the NN NN O
# binding NN NN O
# of NN NN O
# [3H]glibenclamide NN NN B-CHEMICAL
# to NN NN O
# SUR1 NN NN B-GENE-Y
# ( NN NN O
# IC50 NN NN O
# values NN NN O
# : NN NN O
# mitiglinide NN NN B-CHEMICAL
# , NN NN O
# 280 NN NN O
# nM NN NN O
# ; NN NN O
#
# nateglinide NN NN B-CHEMICAL
# , NN NN O
# 8 NN NN O
# microM NN NN O
# ; NN NN O
#
# repaglinide NN NN B-CHEMICAL
# , NN NN O
# 1.6 NN NN O
# microM NN NN O
# ), NN NN O
# suggesting NN NN O
# that NN NN O
# they NN NN O
# all NN NN O
# share NN NN O
# a NN NN O
# glibenclamide NN NN B-CHEMICAL
# binding NN NN O
# site NN NN O
# . NN NN O
#
# The NN NN O
# insulin NN NN B-GENE-N
# responses NN NN O
# to NN NN O
# glucose NN NN B-CHEMICAL
# , NN NN O
# mitiglinide NN NN B-CHEMICAL
# , NN NN O
# tolbutamide NN NN B-CHEMICAL
# , NN NN O
# and NN NN O
# glibenclamide NN NN B-CHEMICAL
# in NN NN O
# MIN6 NN NN O
# cells NN NN O
# after NN NN O
# chronic NN NN O
# mitiglinide NN NN B-CHEMICAL
# , NN NN O
# nateglinide NN NN B-CHEMICAL
# , NN NN O
# or NN NN O
# repaglinide NN NN B-CHEMICAL
# treatment NN NN O
# were NN NN O
# comparable NN NN O
# to NN NN O
# those NN NN O
# after NN NN O
# chronic NN NN O
# tolbutamide NN NN B-CHEMICAL
# and NN NN O
# glibenclamide NN NN B-CHEMICAL
# treatment NN NN O
# . NN NN O
#
# These NN NN O
# results NN NN O
# indicate NN NN O
# that NN NN O
# , NN NN O
# similar NN NN O
# to NN NN O
# the NN NN O
# sulfonylureas NN NN B-CHEMICAL
# , NN NN O
# mitiglinide NN NN B-CHEMICAL
# is NN NN O
# highly NN NN O
# specific NN NN O
# to NN NN O
# the NN NN O
# Kir6.2/SUR1 NN NN O
# complex NN NN O
# , NN NN O
# i.e NN NN O
# ., NN NN O
# the NN NN O
# pancreatic NN NN O
# beta-cell NN NN O
# K(ATP NN NN B-GENE-N
# ) NN NN I-GENE-N
# channel NN NN I-GENE-N
# , NN NN O
# and NN NN O
# suggest NN NN O
# that NN NN O
# mitiglinide NN NN B-CHEMICAL
# may NN NN O
# be NN NN O
# a NN NN O
# clinically NN NN O
# useful NN NN O
# anti-diabetic NN NN O
# drug NN NN O
# . NN NN O
#
# -DOCSTART- -X- -23487168- O
#
# A NN NN O
# systematic NN NN O
# comparison NN NN O
# of NN NN O
# the NN NN O
# properties NN NN O
# of NN NN O
# clinically NN NN O
# used NN NN O
# angiotensin NN NN B-GENE-Y
# II NN NN I-GENE-Y
# type NN NN I-GENE-Y
# 1 NN NN I-GENE-Y
# receptor NN NN I-GENE-Y
# antagonists NN NN O
# . NN NN O
#
# Angiotensin NN NN B-GENE-Y
# II NN NN I-GENE-Y
# type NN NN I-GENE-Y
# 1 NN NN I-GENE-Y
# receptor NN NN I-GENE-Y
# antagonists NN NN O
# ( NN NN O
# ...
# population NN NN O
# in NN NN O
# which NN NN O
# the NN NN O
# G NN NN O
# allele NN NN O
# of NN NN O
# rs5068 NN NN B-GENE-Y
# is NN NN O
# associated NN NN O
# with NN NN O
# lower NN NN O
# blood NN NN O
# pressure NN NN O
# , NN NN O
# BMI NN NN O
# , NN NN O
# and NN NN O
# prevalence NN NN O
# of NN NN O
# hypertension NN NN O
# and NN NN O
# metabolic NN NN O
# syndrome NN NN O
# . NN NN O
#
# These NN NN O
# findings NN NN O
# may NN NN O
# lead NN NN O
# to NN NN O
# a NN NN O
# diagnostic NN NN O
# strategy NN NN O
# to NN NN O
# assess NN NN O
# cardiometabolic NN NN O
# risk NN NN O
# and NN NN O
# lay NN NN O
# the NN NN O
# foundation NN NN O
# for NN NN O
# the NN NN O
# future NN NN O
# development NN NN O
# of NN NN O
# an NN NN O
# ANP NN NN B-GENE-Y
# or NN NN O
# ANP-like NN NN O
# therapy NN NN O
# for NN NN O
# metabolic NN NN O
# syndrome NN NN O
# . NN NN O
#
# -DOCSTART- -X- -1663395- O
#
# The NN NN O
# microsomal/peroxidase NN NN B-GENE-Y
# antigen NN NN I-GENE-Y
# : NN NN O
# modulation NN NN O
# of NN NN O
# its NN NN O
# expression NN NN O
# in NN NN O
# thyroid NN NN O
# cells NN NN O
# . NN NN O
#
# Evidence NN NN O
# has NN NN O
# accumulated NN NN O
# in NN NN O
# the NN NN O
# last NN NN O
# few NN NN O
# years NN NN O
# that NN NN O
# the NN NN O
# expression NN NN O
# of NN NN O
# the NN NN O
# microsomal/peroxidase NN NN B-GENE-Y
# antigen NN NN I-GENE-Y
# ( NN NN O
# M/TPO-Ag NN NN B-GENE-Y
# ) NN NN O
# in NN NN O
# thyroid NN NN O
# cells NN NN O
# is NN NN O
# induced NN NN O
# by NN NN O
# TSH NN NN B-GENE-N
# , NN NN O
# through NN NN O
# pathways NN NN O
# which NN NN O
# involve NN NN O
# intracellular NN NN O
# cAMP NN NN B-CHEMICAL
# accumulation NN NN O
# and NN NN O
# protein NN NN O
# synthesis NN NN O
# . NN NN O
#
# These NN NN O
# data NN NN O
# have NN NN O
# been NN NN O
# found NN NN O
# true NN NN O
# in NN NN O
# any NN NN O
# thyroid NN NN O
# system NN NN O
# studied NN NN O
# so NN NN O
# far NN NN O
# , NN NN O
# both NN NN O
# in NN NN O
# terms NN NN O
# of NN NN O
# immunologic NN NN O
# and NN NN O
# enzymatic NN NN O
# activity NN NN O
# of NN NN O
# TPO NN NN B-GENE-Y
# . NN NN O
#
# TSH NN NN B-GENE-N
# and NN NN O
# cAMP NN NN B-CHEMICAL
# also NN NN O
# increase NN NN O
# the NN NN O
# levels NN NN O
# of NN NN O
# the NN NN O
# specific NN NN O
# mRNA NN NN O
# for NN NN O
# TPO NN NN B-GENE-Y
# in NN NN O
# thyroid NN NN O
# cells NN NN O
# from NN NN O
# different NN NN O
# species NN NN O
# . NN NN O
#
# Whether NN NN O
# this NN NN O
# phenomenon NN NN O
# is NN NN O
# due NN NN O
# to NN NN O
# a NN NN O
# direct NN NN O
# transcriptional NN NN O
# regulation NN NN O
# of NN NN O
# the NN NN O
# TPO NN NN B-GENE-Y
# gene NN NN O
# , NN NN O
# as NN NN O
# shown NN NN O
# in NN NN O
# dog NN NN O
# thyroid NN NN O
# cells NN NN O
# , NN NN O
# or NN NN O
# to NN NN O
# posttranscriptional NN NN O
# effects NN NN O
# , NN NN O
# as NN NN O
# it NN NN O
# would NN NN O
# appear NN NN O
# in NN NN O
# FRTL-5 NN NN O
# cells NN NN O
# , NN NN O
# remains NN NN O
# to NN NN O
# be NN NN O
# clarified NN NN O
# by NN NN O
# future NN NN O
# experiments NN NN O
# . NN NN O
#
# Thyroid NN NN B-GENE-N
# stimulating NN NN I-GENE-N
# antibody NN NN I-GENE-N
# ( NN NN O
# TSAb NN NN B-GENE-N
# ) NN NN O
# of NN NN O
# Graves NN NN O
# ' NN NN O
# disease NN NN O
# also NN NN O
# stimulates NN NN O
# the NN NN O
# expression NN NN O
# of NN NN O
# M/TPO-Ag NN NN B-GENE-Y
# . NN NN O
#
# This NN NN O
# finding NN NN O
# gives NN NN O
# further NN NN O
# support NN NN O
# to NN NN O
# the NN NN O
# relevance NN NN O
# of NN NN O
# TSAb NN NN B-GENE-N
# in NN NN O
# the NN NN O
# pathogenesis NN NN O
# of NN NN O
# hyperthyroidism NN NN O
# and NN NN O
# explains NN NN O
# the NN NN O
# well NN NN O
# known NN NN O
# observation NN NN O
# that NN NN O
# the NN NN O
# " NN NN O
# microsomal NN NN O
# " NN NN O
# antigen NN NN O
# is NN NN O
# particularly NN NN O
# abundant NN NN O
# in NN NN O
# glands NN NN O
# of NN NN O
# Graves NN NN O
# ' NN NN O
# patients NN NN O
# . NN NN O
#
# The NN NN O
# modulation NN NN O
# of NN NN O
# M/TPO-Ag NN NN B-GENE-Y
# surface NN NN O
# expression NN NN O
# by NN NN O
# TSH NN NN B-GENE-N
# can NN NN O
# explain NN NN O
# the NN NN O
# decrease NN NN O
# of NN NN O
# circulating NN NN O
# anti-MAb NN NN O
# observed NN NN O
# during NN NN O
# L-thyroxine NN NN B-CHEMICAL
# therapy NN NN O
# in NN NN O
# hypothyroid NN NN O
# patients NN NN O
# with NN NN O
# Hashimoto's NN NN O
# thyroiditis NN NN O
# . NN NN O
#
# Other NN NN O
# agents NN NN O
# , NN NN O
# such NN NN O
# as NN NN O
# methimazole NN NN B-CHEMICAL
# and NN NN O
# sodium NN NN B-CHEMICAL
# iodide NN NN I-CHEMICAL
# , NN NN O
# which NN NN O
# influence NN NN O
# thyroid NN NN O
# cell NN NN O
# function NN NN O
# , NN NN O
# do NN NN O
# not NN NN O
# directly NN NN O
# interfere NN NN O
# with NN NN O
# the NN NN O
# expression NN NN O
# of NN NN O
# M/TPO-Ag NN NN B-GENE-Y
# . NN NN O
#
# Cytokines NN NN B-GENE-N
# , NN NN O
# such NN NN O
# as NN NN O
# gamma-interferon NN NN B-GENE-Y
# , NN NN O
# interleukin-1 NN NN B-GENE-N
# , NN NN O
# and NN NN O
# interleukin-6 NN NN B-GENE-Y
# have NN NN O
# been NN NN O
# shown NN NN O
# to NN NN O
# inhibit NN NN O
# the NN NN O
# TSH-induced NN NN O
# increase NN NN O
# of NN NN O
# TPO NN NN B-GENE-Y
# mRNA NN NN O
# , NN NN O
# but NN NN O
# further NN NN O
# investigations NN NN O
# are NN NN O
# required NN NN O
# to NN NN O
# elucidate NN NN O
# the NN NN O
# exact NN NN O
# role NN NN O
# of NN NN O
# cytokines NN NN B-GENE-N
# in NN NN O
# the NN NN O
# regulation NN NN O
# of NN NN O
# M/TPO-Ag NN NN B-GENE-Y
# expression NN NN O
# . NN NN O
#
# -DOCSTART- -X- -23569204- O
#
# Structural NN NN O
# and NN NN O
# functional NN NN O
# characterization NN NN O
# of NN NN O
# a NN NN O
# phosphatase NN NN B-GENE-N
# domain NN NN I-GENE-N
# within NN NN O
# yeast NN NN O
# general NN NN O
# transcription NN NN O
# factor NN NN O
# TFIIIC NN NN B-GENE-Y
# . NN NN O
#
# Saccharomyces NN NN B-GENE-Y
# cerevisiae NN NN I-GENE-Y
# τ55 NN NN I-GENE-Y
# , NN NN O
# a NN NN O
# subunit NN NN O
# of NN NN O
# the NN NN O
# RNA NN NN B-GENE-N
# polymerase NN NN I-GENE-N
# III-specific NN NN O
# general NN NN O
# transcription NN NN O
# factor NN NN O
# TFIIIC NN NN B-GENE-Y
# , NN NN O
# comprises NN NN O
# an NN NN O
# N-terminal NN NN B-GENE-N
# histidine NN NN I-GENE-N
# phosphatase NN NN I-GENE-N
# domain NN NN I-GENE-N
# ( NN NN O
# τ55-HPD NN NN O
# ) NN NN O
# whose NN NN O
# catalytic NN NN O
# activity NN NN O
# and NN NN O
# cellular NN NN O
# function NN NN O
# is NN NN O
# poorly NN NN O
# understood NN NN O
# . NN NN O
#
# We NN NN O
# solved NN NN O
# the NN NN O
# crystal NN NN O
# structures NN NN O
# of NN NN O
# τ55-HPD NN NN O
# and NN NN O
# its NN NN O
# closely NN NN O
# related NN NN O
# paralogue NN NN O
# Huf NN NN B-GENE-N
# and NN NN O
# used NN NN O
# in NN NN O
# silico NN NN O
# docking NN NN O
# methods NN NN O
# to NN NN O
# identify NN NN O
# phospho-serine NN NN B-CHEMICAL
# and NN NN O
# phospho-tyrosine NN NN B-CHEMICAL
# containing NN NN O
# peptides NN NN O
# as NN NN O
# possible NN NN O
# substrates NN NN O
# that NN NN O
# were NN NN O
# subsequently NN NN O
# validated NN NN O
# using NN NN O
# in NN NN O
# vitro NN NN O
# phosphatase NN NN B-GENE-N
# assays NN NN O
# . NN NN O
#
# A NN NN O
# comparative NN NN O
# phospho-proteomic NN NN O
# study NN NN O
# identified NN NN O
# additional NN NN O
# phosphopeptides NN NN O
# as NN NN O
# possible NN NN O
# targets NN NN O
# , NN NN O
# which NN NN O
# show NN NN O
# the NN NN O
# involvement NN NN O
# of NN NN O
# these NN NN O
# two NN NN O
# phosphatases NN NN B-GENE-N
# in NN NN O
# the NN NN O
# regulation NN NN O
# of NN NN O
# a NN NN O
# variety NN NN O
# of NN NN O
# cellular NN NN O
# functions NN NN O
# . NN NN O
#
# Our NN NN O
# results NN NN O
# identify NN NN O
# τ55-HPD NN NN O
# and NN NN O
# Huf NN NN O
# as NN NN O
# bona NN NN O
# fide NN NN O
# protein NN NN B-GENE-N
# phosphatases NN NN I-GENE-N
# , NN NN O
# characterize NN NN O
# their NN NN O
# substrate NN NN O
# specificities NN NN O
# and NN NN O
# provide NN NN O
# a NN NN O
# small NN NN O
# set NN NN O
# of NN NN O
# regulated NN NN O
# phosphosite NN NN O
# targets NN NN O
# in NN NN O
# vivo NN NN O
# . NN NN O
#
# -DOCSTART- -X- -23506741- O
#
# A NN NN O
# novel NN NN O
# benzo[d]imidazole NN NN B-CHEMICAL
# derivate NN NN O
# prevents NN NN O
# the NN NN O
# development NN NN O
# of NN NN O
# dextran NN NN O
# sulfate NN NN O
# sodium-induced NN NN O
# murine NN NN O
# experimental NN NN O
# colitis NN NN O
# via NN NN O
# inhibition NN NN O
# of NN NN O
# NLRP3 NN NN B-GENE-Y
# inflammasome NN NN O
# . NN NN O
#
# NLRP3 NN NN B-GENE-Y
# inflammasome NN NN O
# has NN NN O
# been NN NN O
# reported NN NN O
# to NN NN O
# be NN NN O
# associated NN NN O
# with NN NN O
# various NN NN O
# kinds NN NN O
# of NN NN O
# immunological NN NN O
# diseases NN NN O
# including NN NN O
# colitis NN NN O
# . NN NN O
#
# However NN NN O
# , NN NN O
# there NN NN O
# are NN NN O
# few NN NN O
# drug NN NN O
# candidates NN NN O
# targeting NN NN O
# inflammasomes NN NN O
# for NN NN O
# the NN NN O
# treatment NN NN O
# of NN NN O
# colitis NN NN O
# . NN NN O
#
# In NN NN O
# the NN NN O
# present NN NN O
# study NN NN O
# , NN NN O
# we NN NN O
# aimed NN NN O
# at NN NN O
# examining NN NN O
# the NN NN O
# effect NN NN O
# of NN NN O
# 1-ethyl-5-methyl-2-phenyl-1H-benzo[d]imidazole NN NN B-CHEMICAL
# , NN NN O
# a NN NN O
# synthetic NN NN O
# small NN NN O
# molecular NN NN O
# compound NN NN O
# also NN NN O
# named NN NN O
# Fc11a-2 NN NN B-CHEMICAL
# , NN NN O
# for NN NN O
# the NN NN O
# treatment NN NN O
# of NN NN O
# dextran NN NN O
# sulfate NN NN B-CHEMICAL
# sodium NN NN I-CHEMICAL
# ( NN NN O
# DSS)-induced NN NN O
# experimental NN NN O
# colitis NN NN O
# in NN NN O
# mice NN NN O
# via NN NN O
# targeting NN NN O
# NLRP3 NN NN B-GENE-Y
# inflammasome NN NN O
# . NN NN O
#
# Treatment NN NN O
# with NN NN O
# Fc11a-2 NN NN O
# dose-dependently NN NN O
# attenuated NN NN O
# the NN NN O
# loss NN NN O
# of NN NN O
# body NN NN O
# weight NN NN O
# and NN NN O
# shortening NN NN O
# of NN NN O
# colon NN NN O
# length NN NN O
# induced NN NN O
# by NN NN O
# DSS NN NN O
# . NN NN O
#
# In NN NN O
# addition NN NN O
# , NN NN O
# the NN NN O
# disease NN NN O
# activity NN NN O
# index NN NN O
# , NN NN O
# histopathologic NN NN O
# scores NN NN O
# and NN NN O
# myeloperoxidase NN NN B-GENE-N
# activity NN NN O
# were NN NN O
# also NN NN O
# significantly NN NN O
# reduced NN NN O
# by NN NN O
# Fc11a-2 NN NN B-CHEMICAL
# treatment NN NN O
# . NN NN O
#
# Moreover NN NN O
# , NN NN O
# protein NN NN O
# and NN NN O
# mRNA NN NN O
# levels NN NN O
# of NN NN O
# DSS-induced NN NN O
# proinflammatory NN NN O
# cytokines NN NN B-GENE-N
# in NN NN O
# colon NN NN O
# , NN NN O
# including NN NN O
# TNF-α NN NN B-GENE-Y
# , NN NN O
# IL-1β NN NN B-GENE-Y
# , NN NN O
# IL-18 NN NN B-GENE-Y
# , NN NN O
# IL-17A NN NN B-GENE-Y
# and NN NN O
# IFN-γ NN NN B-GENE-Y
# , NN NN O
# were NN NN O
# markedly NN NN O
# suppressed NN NN O
# by NN NN O
# Fc11a-2 NN NN B-CHEMICAL
# . NN NN O
#
# Furthermore NN NN O
# , NN NN O
# a NN NN O
# decreased NN NN O
# CD11c(+ NN NN O
# ) NN NN O
# macrophage NN NN O
# infiltration NN NN O
# in NN NN O
# colons NN NN O
# and NN NN O
# inactivation NN NN O
# of NN NN O
# caspase-1 NN NN B-GENE-Y
# in NN NN O
# peritoneal NN NN O
# macrophages NN NN O
# were NN NN O
# detected NN NN O
# in NN NN O
# Fc11a-2-treated NN NN O
# mice NN NN O
# . NN NN O
#
# The NN NN O
# mechanism NN NN O
# of NN NN O
# action NN NN O
# of NN NN O
# Fc11a-2 NN NN B-CHEMICAL
# was NN NN O
# related NN NN O
# to NN NN O
# the NN NN O
# inhibition NN NN O
# of NN NN O
# the NN NN O
# cleavage NN NN O
# of NN NN O
# pro-caspase-1 NN NN B-GENE-Y
# , NN NN O
# pro-IL-1β NN NN B-GENE-Y
# and NN NN O
# pro-IL-18 NN NN B-GENE-Y
# which NN NN O
# in NN NN O
# turn NN NN O
# suppressed NN NN O
# the NN NN O
# activation NN NN O
# of NN NN O
# NLRP3 NN NN B-GENE-Y
# inflammasome NN NN O
# . NN NN O
#
# Taken NN NN O
# together NN NN O
# , NN NN O
# our NN NN O
# results NN NN O
# demonstrate NN NN O
# the NN NN O
# ability NN NN O
# of NN NN O
# Fc11a-2 NN NN B-CHEMICAL
# to NN NN O
# inhibit NN NN O
# NLRP3 NN NN B-GENE-Y
# inflammasome NN NN O
# activation NN NN O
# and NN NN O
# its NN NN O
# potential NN NN O
# use NN NN O
# in NN NN O
# the NN NN O
# treatment NN NN O
# of NN NN O
# inflammatory NN NN O
# bowel NN NN O
# diseases NN NN O
# . NN NN O
#
# -DOCSTART- -X- -17611273- O
#
# Methylphenidate NN NN B-CHEMICAL
# administration NN NN O
# to NN NN O
# juvenile NN NN O
# rats NN NN O
# alters NN NN O
# brain NN NN O
# areas NN NN O
# involved NN NN O
# in NN NN O
# cognition NN NN O
# , NN NN O
# motivated NN NN O
# behaviors NN NN O
# , NN NN O
# appetite NN NN O
# , NN NN O
# and NN NN O
# stress NN NN O
# . NN NN O
#
# Thousands NN NN O
# of NN NN O
# children NN NN O
# receive NN NN O
# methylphenidate NN NN B-CHEMICAL
# ( NN NN O
# MPH NN NN B-CHEMICAL
# ; NN NN O
#
# Ritalin NN NN B-CHEMICAL
# ) NN NN O
# for NN NN O
# attention NN NN O
# deficit/hyperactivity NN NN O
# disorder NN NN O
# ( NN NN O
# ADHD NN NN O
# ), NN NN O
# yet NN NN O
# the NN NN O
# long-term NN NN O
# neurochemical NN NN O
# consequences NN NN O
# of NN NN O
# MPH NN NN B-CHEMICAL
# treatment NN NN O
# are NN NN O
# unknown NN NN O
# . NN NN O
#
# To NN NN O
# mimic NN NN O
# clinical NN NN O
# Ritalin NN NN B-CHEMICAL
# treatment NN NN O
# in NN NN O
# children NN NN O
# , NN NN O
# male NN NN O
# rats NN NN O
# were NN NN O
# injected NN NN O
# with NN NN O
# MPH NN NN B-CHEMICAL
# ( NN NN O
# 5 NN NN O
# mg/kg NN NN O
# ) NN NN O
# or NN NN O
# vehicle NN NN O
# twice NN NN O
# daily NN NN O
# from NN NN O
# postnatal NN NN O
# day NN NN O
# 7 NN NN O
# ( NN NN O
# PND7)-PND35 NN NN O
# . NN NN O
#
# At NN NN O
# the NN NN O
# end NN NN O
# of NN NN O
# administration NN NN O
# ( NN NN O
# PND35 NN NN O
# ) NN NN O
# or NN NN O
# in NN NN O
# adulthood NN NN O
# ( NN NN O
# PND135 NN NN O
# ), NN NN O
# brain NN NN O
# sections NN NN O
# from NN NN O
# littermate NN NN O
# pairs NN NN O
# were NN NN O
# immunocytochemically NN NN O
# labeled NN NN O
# for NN NN O
# neurotransmitters NN NN O
# and NN NN O
# cytological NN NN O
# markers NN NN O
# in NN NN O
# 16 NN NN O
# regions NN NN O
# implicated NN NN O
# in NN NN O
# MPH NN NN B-CHEMICAL
# effects NN NN O
# and/or NN NN O
# ADHD NN NN O
# etiology NN NN O
# . NN NN O
#
# At NN NN O
# PND35 NN NN O
# , NN NN O
# the NN NN O
# medial NN NN O
# prefrontal NN NN O
# cortex NN NN O
# ( NN NN O
# mPFC NN NN O
# ) NN NN O
# of NN NN O
# rats NN NN O
# given NN NN O
# MPH NN NN B-CHEMICAL
# showed NN NN O
# 55% NN NN O
# greater NN NN O
# immunoreactivity NN NN O
# (- NN NN O
# ir NN NN O
# ) NN NN O
# for NN NN O
# the NN NN O
# catecholamine NN NN B-CHEMICAL
# marker NN NN O
# tyrosine NN NN I-GENE-Y
# hydroxylase NN NN I-GENE-Y
# ( NN NN O
# TH NN NN B-GENE-Y
# ), NN NN O
# 60% NN NN O
# more NN NN O
# Nissl-stained NN NN O
# cells NN NN O
# , NN NN O
# and NN NN O
# 40% NN NN O
# less NN NN O
# norepinephrine NN NN I-GENE-Y
# transporter NN NN I-GENE-Y
# ( NN NN O
# NET)-ir NN NN O
# density NN NN O
# . NN NN O
#
# In NN NN O
# hippocampal NN NN O
# dentate NN NN O
# gyrus NN NN O
# , NN NN O
# MPH-receiving NN NN O
# rats NN NN O
# showed NN NN O
# a NN NN O
# 51% NN NN O
# decrease NN NN O
# in NN NN O
# NET-ir NN NN O
# density NN NN O
# and NN NN O
# a NN NN O
# 61% NN NN O
# expanded NN NN O
# distribution NN NN O
# of NN NN O
# the NN NN O
# new-cell NN NN O
# marker NN NN O
# PSA-NCAM NN NN O
# ( NN NN O
# polysialylated NN NN O
# form NN NN O
# of NN NN O
# neural NN NN B-GENE-Y
# cell NN NN I-GENE-Y
# adhesion NN NN I-GENE-Y
# molecule NN NN I-GENE-Y
# ). NN NN O
#
# In NN NN O
# medial NN NN O
# striatum NN NN O
# , NN NN O
# TH-ir NN NN O
# decreased NN NN O
# by NN NN O
# 21% NN NN O
# , NN NN O
# and NN NN O
# in NN NN O
# hypothalamus NN NN O
# neuropeptide NN NN B-GENE-Y
# Y-ir NN NN O
# increased NN NN O
# by NN NN O
# 10% NN NN O
# in NN NN O
# MPH-exposed NN NN O
# rats NN NN O
# . NN NN O
#
# At NN NN O
# PND135 NN NN O
# , NN NN O
# MPH-exposed NN NN O
# rats NN NN O
# exhibited NN NN O
# decreased NN NN O
# anxiety NN NN O
# in NN NN O
# the NN NN O
# elevated NN NN O
# plus-maze NN NN O
# and NN NN O
# a NN NN O
# trend NN NN O
# for NN NN O
# decreased NN NN O
# TH-ir NN NN O
# in NN NN O
# the NN NN O
# mPFC NN NN O
# . NN NN O
#
# Neither NN NN O
# PND35 NN NN O
# nor NN NN O
# PND135 NN NN O
# rats NN NN O
# showed NN NN O
# major NN NN O
# structural NN NN O
# differences NN NN O
# with NN NN O
# MPH NN NN B-CHEMICAL
# exposure NN NN O
# . NN NN O
#
# These NN NN O
# findings NN NN O
# suggest NN NN O
# that NN NN O
# developmental NN NN O
# exposure NN NN O
# to NN NN O
# high NN NN O
# therapeutic NN NN O
# doses NN NN O
# of NN NN O
# MPH NN NN B-CHEMICAL
# has NN NN O
# short-term NN NN O
# effects NN NN O
# on NN NN O
# select NN NN O
# neurotransmitters NN NN O
# in NN NN O
# brain NN NN O
# regions NN NN O
# involved NN NN O
# in NN NN O
# motivated NN NN O
# behaviors NN NN O
# , NN NN O
# cognition NN NN O
# , NN NN O
# appetite NN NN O
# , NN NN O
# and NN NN O
# stress NN NN O
# . NN NN O
#
# Although NN NN O
# the NN NN O
# observed NN NN O
# neuroanatomical NN NN O
# changes NN NN O
# largely NN NN O
# resolve NN NN O
# with NN NN O
# time NN NN O
# , NN NN O
# chronic NN NN O
# modulation NN NN O
# of NN NN O
# young NN NN O
# brains NN NN O
# with NN NN O
# MPH NN NN B-CHEMICAL
# may NN NN O
# exert NN NN O
# effects NN NN O
# on NN NN O
# brain NN NN O
# neurochemistry NN NN O
# that NN NN O
# modify NN NN O
# some NN NN O
# behaviors NN NN O
# even NN NN O
# in NN NN O
# adulthood NN NN O
# . NN NN O

# %%
with open("train.conll", "w+", encoding='utf8') as f:
    f.write("-DOCSTART- -X- -X- O\n\n")
    f.write(conll_text)

# %%
data = CoNLL().readDataset(spark, "train.conll")
data.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |                text|            document|            sentence|               token|                 pos|               label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |Selective costimu...|[{document, 0, 96...|[{document, 0, 96...|[{token, 0, 8, Se...|[{pos, 0, 8, NN, ...|[{named_entity, 0...|
# |T cells have a ce...|[{document, 0, 17...|[{document, 0, 17...|[{token, 0, 0, T,...|[{pos, 0, 0, NN, ...|[{named_entity, 0...|
# |The requirement f...|[{document, 0, 22...|[{document, 0, 22...|[{token, 0, 2, Th...|[{pos, 0, 2, NN, ...|[{named_entity, 0...|
# |This approach is ...|[{document, 0, 78...|[{document, 0, 78...|[{token, 0, 3, Th...|[{pos, 0, 3, NN, ...|[{named_entity, 0...|
# |it targets events...|[{document, 0, 13...|[{document, 0, 13...|[{token, 0, 1, it...|[{pos, 0, 1, NN, ...|[{named_entity, 0...|
# |The fusion protei...|[{document, 0, 22...|[{document, 0, 22...|[{token, 0, 2, Th...|[{pos, 0, 2, NN, ...|[{named_entity, 0...|
# |Abatacept dose-de...|[{document, 0, 19...|[{document, 0, 19...|[{token, 0, 8, Ab...|[{pos, 0, 8, NN, ...|[{named_entity, 0...|
# |Recent studies ha...|[{document, 0, 25...|[{document, 0, 25...|[{token, 0, 5, Re...|[{pos, 0, 5, NN, ...|[{named_entity, 0...|
# |This efficacy inc...|[{document, 0, 10...|[{document, 0, 10...|[{token, 0, 3, Th...|[{pos, 0, 3, NN, ...|[{named_entity, 0...|
# |Abatacept has als...|[{document, 0, 72...|[{document, 0, 72...|[{token, 0, 8, Ab...|[{pos, 0, 8, NN, ...|[{named_entity, 0...|
# |This article revi...|[{document, 0, 16...|[{document, 0, 16...|[{token, 0, 3, Th...|[{pos, 0, 3, NN, ...|[{named_entity, 0...|
# |This clinical exp...|[{document, 0, 14...|[{document, 0, 14...|[{token, 0, 3, Th...|[{pos, 0, 3, NN, ...|[{named_entity, 0...|
# |Emerging role of ...|[{document, 0, 11...|[{document, 0, 11...|[{token, 0, 7, Em...|[{pos, 0, 7, NN, ...|[{named_entity, 0...|
# |Combination chemo...|[{document, 0, 11...|[{document, 0, 11...|[{token, 0, 10, C...|[{pos, 0, 10, NN,...|[{named_entity, 0...|
# |Meta-analyses hav...|[{document, 0, 18...|[{document, 0, 18...|[{token, 0, 12, M...|[{pos, 0, 12, NN,...|[{named_entity, 0...|
# |Just as important...|[{document, 0, 10...|[{document, 0, 10...|[{token, 0, 3, Ju...|[{pos, 0, 3, NN, ...|[{named_entity, 0...|
# |Newer agents , in...|[{document, 0, 17...|[{document, 0, 17...|[{token, 0, 4, Ne...|[{pos, 0, 4, NN, ...|[{named_entity, 0...|
# |Despite their con...|[{document, 0, 19...|[{document, 0, 19...|[{token, 0, 6, De...|[{pos, 0, 6, NN, ...|[{named_entity, 0...|
# |It is doubtful th...|[{document, 0, 13...|[{document, 0, 13...|[{token, 0, 1, It...|[{pos, 0, 1, NN, ...|[{named_entity, 0...|
# |The thrust of cur...|[{document, 0, 16...|[{document, 0, 16...|[{token, 0, 2, Th...|[{pos, 0, 2, NN, ...|[{named_entity, 0...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows
